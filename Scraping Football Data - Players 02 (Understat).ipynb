# %%
import requests
from bs4 import BeautifulSoup

# %%
import pandas as pd
import json

# %%
#link = "https://understat.com/match/22284"
res = requests.get("https://understat.com/player/1228")
soup = BeautifulSoup(res.content,'lxml')
scripts = soup.find_all('script')

# %%
strings = scripts[1].string 
ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')
data = json.loads(json_data)
# Out:
# {'season': [{'position': 'MC',
#    'games': '23',
#    'goals': '3',
#    'shots': '56',
#    'time': '2070',
#    'xG': '5.442168924026191',
#    'assists': '5',
#    'xA': '8.100289855152369',
#    'key_passes': '70',
#    'season': '2023',
#    'team': 'Manchester United',
#    'yellow': '7',
#    'red': '0',
#    'npg': '2',
#    'npxG': '3.9198311595246196',
#    'xGChain': '13.199519656598568',
#    'xGBuildup': '7.296374291181564'},
#   {'position': 'MC',
#    'games': '37',
#    'goals': '8',
#    'shots': '92',
#    'time': '3326',
#    'xG': '9.385456696152687',
#    'assists': '8',
#    'xA': '17.266709440387785',
#    'key_passes': '118',
#    'season': '2022',
#    'team': 'Manchester United',
#    'yellow': '6',
#    'red': '0',
#    'npg': '6',
#    'npxG': '7.863118812441826',
#    'xGChain': '35.418096881359816',
#    'xGBuildup': '17.724953144788742'},
#   {'position': 'AMC',
#    'games': '36',
#    'goals': '10',
#    'shots': '89',
#    'time': '3135',
#    'xG': '9.285304862074554',
#    'assists': '6',
#    'xA': '8.811852657236159',
#    'key_passes': '88',
#    'season': '2021',
#    'team': 'Manchester United',
#    'yellow': '10',
#    'red': '0',
#    'npg': '10',
#    'npxG': '7.762967492453754',
#    'xGChain': '22.98672279715538',
#    'xGBuildup': '11.14225958287716'},
#   {'position': 'AMC',
#    'games': '37',
#    'goals': '18',
#    'shots': '121',
#    'time': '3117',
#    'xG': '16.019450719468296',
#    'assists': '12',
#    'xA': '11.474997889250517',
#    'key_passes': '95',
#    'season': '2020',
#    'team': 'Manchester United',
#    'yellow': '6',
#    'red': '0',
#    'npg': '9',
#    'npxG': '8.407837779261172',
#    'xGChain': '26.91141940653324',
#    'xGBuildup': '11.932286506518722'},
#   {'position': 'AMC',
#    'games': '14',
#    'goals': '8',
#    'shots': '44',
#    'time': '1211',
#    'xG': '5.98607742600143',
#    'assists': '7',
#    'xA': '2.7549998983740807',
#    'key_passes': '30',
#    'season': '2019',
#    'team': 'Manchester United',
#    'yellow': '2',
#    'red': '0',
#    'npg': '4',
#    'npxG': '2.9414413776248693',
#    'xGChain': '8.513753656297922',
#    'xGBuildup': '4.864240288734436'},
#   {'position': 'Sub',
#    'games': '33',
#    'goals': '5',
#    'shots': '62',
#    'time': '1736',
#    'xG': '5.761577281169593',
#    'assists': '2',
#    'xA': '4.4775946363806725',
#    'key_passes': '52',
#    'season': '2016',
#    'team': 'Sampdoria',
#    'yellow': '2',
#    'red': '0',
#    'npg': '5',
#    'npxG': '5.761577281169593',
#    'xGChain': '11.588001352734864',
#    'xGBuildup': '3.9690468413755298'},
#   {'position': 'MC',
#    'games': '31',
#    'goals': '3',
#    'shots': '52',
#    'time': '2116',
#    'xG': '3.79332700651139',
#    'assists': '4',
#    'xA': '3.7490005446597934',
#    'key_passes': '44',
#    'season': '2015',
#    'team': 'Udinese',
#    'yellow': '7',
#    'red': '1',
#    'npg': '2',
#    'npxG': '2.2707290379330516',
#    'xGChain': '8.635709737427533',
#    'xGBuildup': '4.768451112322509'},
#   {'position': 'Sub',
#    'games': '31',
#    'goals': '3',
#    'shots': '41',
#    'time': '1605',
#    'xG': '2.634341513738036',
#    'assists': '2',
#    'xA': '2.331952504813671',
#    'key_passes': '22',
#    'season': '2014',
#    'team': 'Udinese',
#    'yellow': '5',
#    'red': '0',
#    'npg': '3',
#    'npxG': '2.634341513738036',
#    'xGChain': '5.787391685880721',
#    'xGBuildup': '2.2256615795195103'}],
#  'position': {'2023': {'AMC': {'position': 'AMC',
#     'games': '19',
#     'goals': '2',
#     'shots': '45',
#     'time': '1710',
#     'xG': '4.792987785302103',
#     'assists': '5',
#     'xA': '7.526210632175207',
#     'key_passes': '62',
#     'season': '2023',
#     'yellow': '6',
#     'red': '0',
#     'npg': '1',
#     'npxG': '3.270650020800531',
#     'xGChain': '10.732586733996868',
#     'xGBuildup': '5.740406826138496'},
#    'AMR': {'position': 'AMR',
#     'games': '3',
#     'goals': '1',
#     'shots': '10',
#     'time': '270',
#     'xG': '0.632633626461029',
#     'assists': '0',
#     'xA': '0.2651810422539711',
#     'key_passes': '5',
#     'season': '2023',
#     'yellow': '1',
#     'red': '0',
#     'npg': '1',
#     'npxG': '0.632633626461029',
#     'xGChain': '1.3941647112369537',
#     'xGBuildup': '0.706288531422615'},
#    'MC': {'position': 'MC',
#     'games': '1',
#     'goals': '0',
#     'shots': '1',
#     'time': '90',
#     'xG': '0.016547512263059616',
#     'assists': '0',
#     'xA': '0.3088981807231903',
#     'key_passes': '3',
#     'season': '2023',
#     'yellow': '0',
#     'red': '0',
#     'npg': '0',
#     'npxG': '0.016547512263059616',
#     'xGChain': '1.072768211364746',
#     'xGBuildup': '0.8496789336204529'}},
#   '2022': {'AMC': {'position': 'AMC',
#     'games': '26',
#     'goals': '6',
#     'shots': '67',
#     'time': '2336',
#     'xG': '7.438450904563069',
#     'assists': '5',
#     'xA': '10.198626049794257',
#     'key_passes': '79',
#     'season': '2022',
#     'yellow': '5',
#     'red': '0',
#     'npg': '4',
#     'npxG': '5.916113020852208',
#     'xGChain': '23.945894669741392',
#     'xGBuildup': '13.256883010268211'},
#    'AMR': {'position': 'AMR',
#     'games': '3',
#     'goals': '1',
#     'shots': '8',
#     'time': '270',
#     'xG': '0.6956530064344406',
#     'assists': '3',
#     'xA': '3.3869400024414062',
#     'key_passes': '14',
#     'season': '2022',
#     'yellow': '0',
#     'red': '0',
#     'npg': '1',
#     'npxG': '0.6956530064344406',
#     'xGChain': '5.674190044403076',
#     'xGBuildup': '1.7650649845600128'},
#    'MC': {'position': 'MC',
#     'games': '3',
#     'goals': '0',
#     'shots': '5',
#     'time': '270',
#     'xG': '0.23019780963659286',
#     'assists': '0',
#     'xA': '1.5511826574802399',
#     'key_passes': '9',
#     'season': '2022',
#     'yellow': '0',
#     'red': '0',
#     'npg': '0',
#     'npxG': '0.23019780963659286',
#     'xGChain': '1.8387940227985382',
#     'xGBuildup': '0.5520040616393089'},
#    'AML': {'position': 'AML',
#     'games': '2',
#     'goals': '0',
#     'shots': '5',
#     'time': '180',
#     'xG': '0.1914479210972786',
#     'assists': '0',
#     'xA': '0.8254640996456146',
#     'key_passes': '6',
#     'season': '2022',
#     'yellow': '0',
#     'red': '0',
#     'npg': '0',
#     'npxG': '0.1914479210972786',
#     'xGChain': '1.0212895572185516',
#     'xGBuildup': '0.5013101175427437'},
#    'DMC': {'position': 'DMC',
#     'games': '2',
#     'goals': '0',
#     'shots': '5',
#     'time': '180',
#     'xG': '0.4430330079048872',
#     'assists': '0',
#     'xA': '0.976869985461235',
#     'key_passes': '9',
#     'season': '2022',
#     'yellow': '1',
#     'red': '0',
#     'npg': '0',
#     'npxG': '0.4430330079048872',
#     'xGChain': '2.03152397274971',
#     'xGBuildup': '1.4575870335102081'},
#    'MR': {'position': 'MR',
#     'games': '1',
#     'goals': '1',
#     'shots': '2',
#     'time': '90',
#     'xG': '0.38667404651641846',
#     'assists': '0',
#     'xA': '0.32762664556503296',
#     'key_passes': '1',
#     'season': '2022',
#     'yellow': '0',
#     'red': '0',
#     'npg': '1',
#     'npxG': '0.38667404651641846',
#     'xGChain': '0.9064046144485474',
#     'xGBuildup': '0.19210393726825714'}},
#   '2021': {'AMC': {'position': 'AMC',
#     'games': '28',
#     'goals': '9',
#     'shots': '63',
#     'time': '2476',
#     'xG': '6.694973829202354',
#     'assists': '6',
#     'xA': '7.842104258947074',
#     'key_passes': '79',
#     'season': '2021',
#     'yellow': '10',
#     'red': '0',
#     'npg': '9',
#     'npxG': '5.172636459581554',
#     'xGChain': '18.25581879168749',
#     'xGBuildup': '9.00605158507824'},
#    'AML': {'position': 'AML',
#     'games': '3',
#     'goals': '1',
#     'shots': '15',
#     'time': '270',
#     'xG': '1.8510341122746468',
#     'assists': '0',
#     'xA': '0.6587570011615753',
#     'key_passes': '5',
#     'season': '2021',
#     'yellow': '0',
#     'red': '0',
#     'npg': '1',
#     'npxG': '1.8510341122746468',
#     'xGChain': '2.9207890033721924',
#     'xGBuildup': '1.1211509704589844'},
#    'MC': {'position': 'MC',
#     'games': '2',
#     'goals': '0',
#     'shots': '4',
#     'time': '180',
#     'xG': '0.11685980297625065',
#     'assists': '0',
#     'xA': '0.09007179737091064',
#     'key_passes': '1',
#     'season': '2021',
#     'yellow': '0',
#     'red': '0',
#     'npg': '0',
#     'npxG': '0.11685980297625065',
#     'xGChain': '0.7768729999661446',
#     'xGBuildup': '0.641677625477314'},
#    'FW': {'position': 'FW',
#     'games': '2',
#     'goals': '0',
#     'shots': '5',
#     'time': '180',
#     'xG': '0.2045471053570509',
#     'assists': '0',
#     'xA': '0.11788859777152538',
#     'key_passes': '2',
#     'season': '2021',
#     'yellow': '0',
#     'red': '0',
#     'npg': '0',
#     'npxG': '0.2045471053570509',
#     'xGChain': '0.4982580095529556',
#     'xGBuildup': '0.2682354003190994'},
#    'Sub': {'position': 'Sub',
#     'games': '1',
#     'goals': '0',
#     'shots': '2',
#     'time': '29',
#     'xG': '0.4178900122642517',
#     'assists': '0',
#     'xA': '0.10303100198507309',
#     'key_passes': '1',
#     'season': '2021',
#     'yellow': '0',
#     'red': '0',
#     'npg': '0',
#     'npxG': '0.4178900122642517',
#     'xGChain': '0.5349839925765991',
#     'xGBuildup': '0.10514400154352188'}},
#   '2020': {'AMC': {'position': 'AMC',
#     'games': '35',
#     'goals': '18',
#     'shots': '120',
#     'time': '3063',
#     'xG': '15.958003520034254',
#     'assists': '11',
#     'xA': '10.437017928808928',
#     'key_passes': '87',
#     'season': '2020',
#     'yellow': '6',
#     'red': '0',
#     'npg': '9',
#     'npxG': '8.34639057982713',
#     'xGChain': '25.272706143558025',
#     'xGBuildup': '10.893280424177647'},
#    'Sub': {'position': 'Sub',
#     'games': '2',
#     'goals': '0',
#     'shots': '1',
#     'time': '54',
#     'xG': '0.06144719943404198',
#     'assists': '1',
#     'xA': '1.0379799604415894',
#     'key_passes': '8',
#     'season': '2020',
#     'yellow': '0',
#     'red': '0',
#     'npg': '0',
#     'npxG': '0.06144719943404198',
#     'xGChain': '1.638713262975216',
#     'xGBuildup': '1.039006082341075'}},
#   '2019': {'AMC': {'position': 'AMC',
#     'games': '14',
#     'goals': '8',
#     'shots': '44',
#     'time': '1211',
#     'xG': '5.98607742600143',
#     'assists': '7',
#     'xA': '2.7549998983740807',
#     'key_passes': '30',
#     'season': '2019',
#     'yellow': '2',
#     'red': '0',
#     'npg': '4',
#     'npxG': '2.9414413776248693',
#     'xGChain': '8.513753656297922',
#     'xGBuildup': '4.864240288734436'}},
#   '2016': {'AMC': {'position': 'AMC',
#     'games': '22',
#     'goals': '2',
#     'shots': '45',
#     'time': '1498',
#     'xG': '3.7012123046442866',
#     'assists': '2',
#     'xA': '3.7751502320170403',
#     'key_passes': '40',
#     'season': '2016',
#     'yellow': '2',
#     'red': '0',
#     'npg': '2',
#     'npxG': '3.7012123046442866',
#     'xGChain': '8.606621077284217',
#     'xGBuildup': '3.1567048467695713'},
#    'Sub': {'position': 'Sub',
#     'games': '11',
#     'goals': '3',
#     'shots': '17',
#     'time': '238',
#     'xG': '2.0603649765253067',
#     'assists': '0',
#     'xA': '0.7024444043636322',
#     'key_passes': '12',
#     'season': '2016',
#     'yellow': '0',
#     'red': '0',
#     'npg': '3',
#     'npxG': '2.0603649765253067',
#     'xGChain': '2.981380275450647',
#     'xGBuildup': '0.8123419946059585'}},
#   '2015': {'MC': {'position': 'MC',
#     'games': '18',
#     'goals': '2',
#     'shots': '35',
#     'time': '1436',
#     'xG': '3.061712517403066',
#     'assists': '4',
#     'xA': '2.698641385883093',
#     'key_passes': '33',
#     'season': '2015',
#     'yellow': '6',
#     'red': '1',
#     'npg': '1',
#     'npxG': '1.5391145488247275',
#     'xGChain': '5.2796635273844',
#     'xGBuildup': '2.6493732258677483'},
#    'AMC': {'position': 'AMC',
#     'games': '3',
#     'goals': '0',
#     'shots': '8',
#     'time': '237',
#     'xG': '0.15324300155043602',
#     'assists': '0',
#     'xA': '0.46392399072647095',
#     'key_passes': '2',
#     'season': '2015',
#     'yellow': '0',
#     'red': '0',
#     'npg': '0',
#     'npxG': '0.15324300155043602',
#     'xGChain': '0.9084170125424862',
#     'xGBuildup': '0.6765763089060783'},
#    'Sub': {'position': 'Sub',
#     'games': '7',
#     'goals': '0',
#     'shots': '4',
#     'time': '182',
#     'xG': '0.17631299793720245',
#     'assists': '0',
#     'xA': '0.3007461717352271',
#     'key_passes': '2',
#     'season': '2015',
#     'yellow': '1',
#     'red': '0',
#     'npg': '0',
#     'npxG': '0.17631299793720245',
#     'xGChain': '1.3829382052645087',
#     'xGBuildup': '0.9435782907530665'},
#    'FWR': {'position': 'FWR',
#     'games': '2',
#     'goals': '0',
#     'shots': '2',
#     'time': '171',
#     'xG': '0.028145499527454376',
#     'assists': '0',
#     'xA': '0.15280699729919434',
#     'key_passes': '3',
#     'season': '2015',
#     'yellow': '0',
#     'red': '0',
#     'npg': '0',
#     'npxG': '0.028145499527454376',
#     'xGChain': '0.5804279893636703',
#     'xGBuildup': '0.4471624866127968'},
#    'FWL': {'position': 'FWL',
#     'games': '1',
#     'goals': '1',
#     'shots': '3',
#     'time': '90',
#     'xG': '0.3739129900932312',
#     'assists': '0',
#     'xA': '0.1328819990158081',
#     'key_passes': '4',
#     'season': '2015',
#     'yellow': '0',
#     'red': '0',
#     'npg': '1',
#     'npxG': '0.3739129900932312',
#     'xGChain': '0.48426300287246704',
#     'xGBuildup': '0.051760800182819366'}},
#   '2014': {'AMC': {'position': 'AMC',
#     'games': '9',
#     'goals': '1',
#     'shots': '15',
#     'time': '657',
#     'xG': '0.6746141137555242',
#     'assists': '1',
#     'xA': '1.2541894931346178',
#     'key_passes': '10',
#     'season': '2014',
#     'yellow': '3',
#     'red': '0',
#     'npg': '1',
#     'npxG': '0.6746141137555242',
#     'xGChain': '1.911897785961628',
#     'xGBuildup': '0.9104025717824697'},
#    'Sub': {'position': 'Sub',
#     'games': '15',
#     'goals': '1',
#     'shots': '13',
#     'time': '392',
#     'xG': '1.2900029914453626',
#     'assists': '0',
#     'xA': '0.5037667136639357',
#     'key_passes': '7',
#     'season': '2014',
#     'yellow': '0',
#     'red': '0',
#     'npg': '1',
#     'npxG': '1.2900029914453626',
#     'xGChain': '2.382016991265118',
#     'xGBuildup': '0.9741840120404959'},
#    'MC': {'position': 'MC',
#     'games': '4',
#     'goals': '1',
#     'shots': '11',
#     'time': '360',
#     'xG': '0.3874034024775028',
#     'assists': '1',
#     'xA': '0.17886929959058762',
#     'key_passes': '4',
#     'season': '2014',
#     'yellow': '1',
#     'red': '0',
#     'npg': '1',
#     'npxG': '0.3874034024775028',
#     'xGChain': '0.49057990685105324',
#     'xGBuildup': '0.015626199543476105'},
#    'ML': {'position': 'ML',
#     'games': '3',
#     'goals': '0',
#     'shots': '2',
#     'time': '196',
#     'xG': '0.2823210060596466',
#     'assists': '0',
#     'xA': '0.39512699842453003',
#     'key_passes': '1',
#     'season': '2014',
#     'yellow': '1',
#     'red': '0',
#     'npg': '0',
#     'npxG': '0.2823210060596466',
#     'xGChain': '1.0028970018029213',
#     'xGBuildup': '0.32544879615306854'}}},
#  'situation': {'2014': {'OpenPlay': {'situation': 'OpenPlay',
#     'season': '2014',
#     'goals': '3',
#     'shots': '39',
#     'xG': '2.584113920573145',
#     'assists': '2',
#     'key_passes': '20',
#     'xA': '2.2289728177711368',
#     'npg': '3',
#     'npxG': '2.584113920573145',
#     'time': 1605},
#    'DirectFreekick': {'situation': 'DirectFreekick',
#     'season': '2014',
#     'goals': '0',
#     'shots': '1',
#     'xG': '0.03456370159983635',
#     'assists': '0',
#     'key_passes': '0',
#     'xA': '0',
#     'npg': '0',
#     'npxG': '0.03456370159983635',
#     'time': 1605},
#    'FromCorner': {'situation': 'FromCorner',
#     'season': '2014',
#     'goals': '0',
#     'shots': '1',
#     'xG': '0.01566370017826557',
#     'assists': '0',
#     'key_passes': '2',
#     'xA': '0.1029789000749588',
#     'npg': '0',
#     'npxG': '0.01566370017826557',
#     'time': 1605}},
#   '2015': {'OpenPlay': {'situation': 'OpenPlay',
#     'season': '2015',
#     'goals': '2',
#     'shots': '39',
#     'xG': '1.905363332014531',
#     'assists': '2',
#     'key_passes': '31',
#     'xA': '2.32641617115587',
#     'npg': '2',
#     'npxG': '1.905363332014531',
#     'time': 2116},
#    'DirectFreekick': {'situation': 'DirectFreekick',
#     'season': '2015',
#     'goals': '0',
#     'shots': '5',
#     'xG': '0.29090990498661995',
#     'assists': '0',
#     'key_passes': '0',
#     'xA': '0',
#     'npg': '0',
#     'npxG': '0.29090990498661995',
#     'time': 2116},
#    'FromCorner': {'situation': 'FromCorner',
#     'season': '2015',
#     'goals': '0',
#     'shots': '3',
#     'xG': '0.03863577963784337',
#     'assists': '2',
#     'key_passes': '9',
#     'xA': '1.2467850297689438',
#     'npg': '0',
#     'npxG': '0.03863577963784337',
#     'time': 2116},
#    'SetPiece': {'situation': 'SetPiece',
#     'season': '2015',
#     'goals': '0',
#     'shots': '3',
#     'xG': '0.03582107927650213',
#     'assists': '0',
#     'key_passes': '4',
#     'xA': '0.17580140009522438',
#     'npg': '0',
#     'npxG': '0.03582107927650213',
#     'time': 2116},
#    'Penalty': {'situation': 'Penalty',
#     'season': '2015',
#     'goals': '1',
#     'shots': '2',
#     'xG': '1.5225980281829834',
#     'assists': '0',
#     'key_passes': '0',
#     'xA': '0',
#     'npg': '0',
#     'npxG': '0',
#     'time': 2116}},
#   '2016': {'OpenPlay': {'situation': 'OpenPlay',
#     'season': '2016',
#     'goals': '5',
#     'shots': '51',
#     'xG': '5.305505812168121',
#     'assists': '2',
#     'key_passes': '40',
#     'xA': '3.6506686313077807',
#     'npg': '5',
#     'npxG': '5.305505812168121',
#     'time': 1736},
#    'DirectFreekick': {'situation': 'DirectFreekick',
#     'season': '2016',
#     'goals': '0',
#     'shots': '6',
#     'xG': '0.36652619764208794',
#     'assists': '0',
#     'key_passes': '0',
#     'xA': '0',
#     'npg': '0',
#     'npxG': '0.36652619764208794',
#     'time': 1736},
#    'FromCorner': {'situation': 'FromCorner',
#     'season': '2016',
#     'goals': '0',
#     'shots': '4',
#     'xG': '0.07900899928063154',
#     'assists': '0',
#     'key_passes': '7',
#     'xA': '0.6299737095832825',
#     'npg': '0',
#     'npxG': '0.07900899928063154',
#     'time': 1736},
#    'SetPiece': {'situation': 'SetPiece',
#     'season': '2016',
#     'goals': '0',
#     'shots': '1',
#     'xG': '0.010536500252783298',
#     'assists': '0',
#     'key_passes': '5',
#     'xA': '0.19695270154625177',
#     'npg': '0',
#     'npxG': '0.010536500252783298',
#     'time': 1736}},
#   '2019': {'OpenPlay': {'situation': 'OpenPlay',
#     'season': '2019',
#     'goals': '3',
#     'shots': '30',
#     'xG': '2.3756171287968755',
#     'assists': '4',
#     'key_passes': '21',
#     'xA': '2.2154289754107594',
#     'npg': '3',
#     'npxG': '2.3756171287968755',
#     'time': 1211},
#    'DirectFreekick': {'situation': 'DirectFreekick',
#     'season': '2019',
#     'goals': '1',
#     'shots': '7',
#     'xG': '0.47313859313726425',
#     'assists': '0',
#     'key_passes': '0',
#     'xA': '0',
#     'npg': '1',
#     'npxG': '0.47313859313726425',
#     'time': 1211},
#    'Penalty': {'situation': 'Penalty',
#     'season': '2019',
#     'goals': '4',
#     'shots': '4',
#     'xG': '3.0446390509605408',
#     'assists': '0',
#     'key_passes': '0',
#     'xA': '0',
#     'npg': '0',
#     'npxG': '0',
#     'time': 1211},
#    'FromCorner': {'situation': 'FromCorner',
#     'season': '2019',
#     'goals': '0',
#     'shots': '3',
#     'xG': '0.0926853995770216',
#     'assists': '2',
#     'key_passes': '7',
#     'xA': '0.4032485019415617',
#     'npg': '0',
#     'npxG': '0.0926853995770216',
#     'time': 1211},
#    'SetPiece': {'situation': 'SetPiece',
#     'season': '2019',
#     'goals': '0',
#     'shots': '0',
#     'xG': '0',
#     'assists': '1',
#     'key_passes': '2',
#     'xA': '0.1363214012235403',
#     'npg': '0',
#     'npxG': '0',
#     'time': 1211}},
#   '2020': {'OpenPlay': {'situation': 'OpenPlay',
#     'season': '2020',
#     'goals': '9',
#     'shots': '83',
#     'xG': '6.713551850989461',
#     'assists': '12',
#     'key_passes': '75',
#     'xA': '10.773803134448826',
#     'npg': '9',
#     'npxG': '6.713551850989461',
#     'time': 3117},
#    'DirectFreekick': {'situation': 'DirectFreekick',
#     'season': '2020',
#     'goals': '0',
#     'shots': '16',
#     'xG': '1.0886806044727564',
#     'assists': '0',
#     'key_passes': '0',
#     'xA': '0',
#     'npg': '0',
#     'npxG': '1.0886806044727564',
#     'time': 3117},
#    'FromCorner': {'situation': 'FromCorner',
#     'season': '2020',
#     'goals': '0',
#     'shots': '11',
#     'xG': '0.3091200115159154',
#     'assists': '0',
#     'key_passes': '18',
#     'xA': '0.580953748896718',
#     'npg': '0',
#     'npxG': '0.3091200115159154',
#     'time': 3117},
#    'Penalty': {'situation': 'Penalty',
#     'season': '2020',
#     'goals': '9',
#     'shots': '10',
#     'xG': '7.611616134643555',
#     'assists': '0',
#     'key_passes': '0',
#     'xA': '0',
#     'npg': '0',
#     'npxG': '0',
#     'time': 3117},
#    'SetPiece': {'situation': 'SetPiece',
#     'season': '2020',
#     'goals': '0',
#     'shots': '1',
#     'xG': '0.2964879870414734',
#     'assists': '0',
#     'key_passes': '2',
#     'xA': '0.12024029716849327',
#     'npg': '0',
#     'npxG': '0.2964879870414734',
#     'time': 3117}},
#   '2021': {'OpenPlay': {'situation': 'OpenPlay',
#     'season': '2021',
#     'goals': '8',
#     'shots': '68',
#     'xG': '6.663604947738349',
#     'assists': '6',
#     'key_passes': '68',
#     'xA': '6.647013827227056',
#     'npg': '8',
#     'npxG': '6.663604947738349',
#     'time': 3135},
#    'FromCorner': {'situation': 'FromCorner',
#     'season': '2021',
#     'goals': '0',
#     'shots': '11',
#     'xG': '0.25631790049374104',
#     'assists': '0',
#     'key_passes': '15',
#     'xA': '1.2039670841768384',
#     'npg': '0',
#     'npxG': '0.25631790049374104',
#     'time': 3135},
#    'DirectFreekick': {'situation': 'DirectFreekick',
#     'season': '2021',
#     'goals': '0',
#     'shots': '6',
#     'xG': '0.3878620006144047',
#     'assists': '0',
#     'key_passes': '0',
#     'xA': '0',
#     'npg': '0',
#     'npxG': '0.3878620006144047',
#     'time': 3135},
#    'Penalty': {'situation': 'Penalty',
#     'season': '2021',
#     'goals': '0',
#     'shots': '2',
#     'xG': '1.5223380327224731',
#     'assists': '0',
#     'key_passes': '0',
#     'xA': '0',
#     'npg': '0',
#     'npxG': '0',
#     'time': 3135},
#    'SetPiece': {'situation': 'SetPiece',
#     'season': '2021',
#     'goals': '2',
#     'shots': '2',
#     'xG': '0.45518529042601585',
#     'assists': '0',
#     'key_passes': '4',
#     'xA': '0.960871385410428',
#     'npg': '2',
#     'npxG': '0.45518529042601585',
#     'time': 3135}},
#   '2022': {'OpenPlay': {'situation': 'OpenPlay',
#     'season': '2022',
#     'goals': '6',
#     'shots': '79',
#     'xG': '7.253958882763982',
#     'assists': '8',
#     'key_passes': '88',
#     'xA': '14.336424613371491',
#     'npg': '6',
#     'npxG': '7.253958882763982',
#     'time': 3326},
#    'DirectFreekick': {'situation': 'DirectFreekick',
#     'season': '2022',
#     'goals': '0',
#     'shots': '6',
#     'xG': '0.4032558798789978',
#     'assists': '0',
#     'key_passes': '0',
#     'xA': '0',
#     'npg': '0',
#     'npxG': '0.4032558798789978',
#     'time': 3326},
#    'FromCorner': {'situation': 'FromCorner',
#     'season': '2022',
#     'goals': '0',
#     'shots': '5',
#     'xG': '0.2059037685394287',
#     'assists': '0',
#     'key_passes': '27',
#     'xA': '2.0791266644373536',
#     'npg': '0',
#     'npxG': '0.2059037685394287',
#     'time': 3326},
#    'Penalty': {'situation': 'Penalty',
#     'season': '2022',
#     'goals': '2',
#     'shots': '2',
#     'xG': '1.5223378539085388',
#     'assists': '0',
#     'key_passes': '0',
#     'xA': '0',
#     'npg': '0',
#     'npxG': '0',
#     'time': 3326},
#    'SetPiece': {'situation': 'SetPiece',
#     'season': '2022',
#     'goals': '0',
#     'shots': '0',
#     'xG': '0',
#     'assists': '0',
#     'key_passes': '3',
#     'xA': '0.8511593155562878',
#     'npg': '0',
#     'npxG': '0',
#     'time': 3326}},
#   '2023': {'OpenPlay': {'situation': 'OpenPlay',
#     'season': '2023',
#     'goals': '2',
#     'shots': '39',
#     'xG': '3.2412159321829677',
#     'assists': '3',
#     'key_passes': '41',
#     'xA': '4.37929099239409',
#     'npg': '2',
#     'npxG': '3.2412159321829677',
#     'time': 2070},
#    'DirectFreekick': {'situation': 'DirectFreekick',
#     'season': '2023',
#     'goals': '0',
#     'shots': '9',
#     'xG': '0.5655433237552643',
#     'assists': '0',
#     'key_passes': '0',
#     'xA': '0',
#     'npg': '0',
#     'npxG': '0.5655433237552643',
#     'time': 2070},
#    'FromCorner': {'situation': 'FromCorner',
#     'season': '2023',
#     'goals': '0',
#     'shots': '6',
#     'xG': '0.11307196225970984',
#     'assists': '1',
#     'key_passes': '23',
#     'xA': '1.9656379828229547',
#     'npg': '0',
#     'npxG': '0.11307196225970984',
#     'time': 2070},
#    'Penalty': {'situation': 'Penalty',
#     'season': '2023',
#     'goals': '1',
#     'shots': '2',
#     'xG': '1.5223376750946045',
#     'assists': '0',
#     'key_passes': '0',
#     'xA': '0',
#     'npg': '0',
#     'npxG': '0',
#     'time': 2070},
#    'SetPiece': {'situation': 'SetPiece',
#     'season': '2023',
#     'goals': '0',
#     'shots': '0',
#     'xG': '0',
#     'assists': '1',
#     'key_passes': '6',
#     'xA': '1.7553608044981956',
#     'npg': '0',
#     'npxG': '0',
#     'time': 2070}}},
#  'shotZones': {'2014': {'shotOboxTotal': {'shotZones': 'shotOboxTotal',
#     'season': '2014',
#     'goals': '2',
#     'shots': '29',
#     'xG': '0.740115859080106',
#     'assists': '0',
#     'key_passes': '6',
#     'xA': '0.13570029940456152',
#     'npg': '2',
#     'npxG': '0.740115859080106'},
#    'shotPenaltyArea': {'shotZones': 'shotPenaltyArea',
#     'season': '2014',
#     'goals': '1',
#     'shots': '11',
#     'xG': '1.7750454619526863',
#     'assists': '2',
#     'key_passes': '16',
#     'xA': '2.196251418441534',
#     'npg': '1',
#     'npxG': '1.7750454619526863'},
#    'shotSixYardBox': {'shotZones': 'shotSixYardBox',
#     'season': '2014',
#     'goals': '0',
#     'shots': '1',
#     'xG': '0.11918000131845474',
#     'assists': '0',
#     'key_passes': '0',
#     'xA': '0',
#     'npg': '0',
#     'npxG': '0.11918000131845474'}},
#   '2015': {'shotOboxTotal': {'shotZones': 'shotOboxTotal',
#     'season': '2015',
#     'goals': '0',
#     'shots': '38',
#     'xG': '1.012870474718511',
#     'assists': '0',
#     'key_passes': '8',
#     'xA': '0.1966842832043767',
#     'npg': '0',
#     'npxG': '1.012870474718511'},
#    'shotPenaltyArea': {'shotZones': 'shotPenaltyArea',
#     'season': '2015',
#     'goals': '3',
#     'shots': '14',
#     'xG': '2.7804576493799686',
#     'assists': '3',
#     'key_passes': '34',
#     'xA': '2.919386303052306',
#     'npg': '2',
#     'npxG': '1.2578596211969852'},
#    'shotSixYardBox': {'shotZones': 'shotSixYardBox',
#     'season': '2015',
#     'goals': '0',
#     'shots': '0',
#     'xG': '0',
#     'assists': '1',
#     'key_passes': '2',
#     'xA': '0.6329320147633553',
#     'npg': '0',
#     'npxG': '0'}},
#   '2016': {'shotOboxTotal': {'shotZones': 'shotOboxTotal',
#     'season': '2016',
#     'goals': '2',
#     'shots': '41',
#     'xG': '1.1016132682561874',
#     'assists': '0',
#     'key_passes': '23',
#     'xA': '0.5608574282377958',
#     'npg': '2',
#     'npxG': '1.1016132682561874'},
#    'shotPenaltyArea': {'shotZones': 'shotPenaltyArea',
#     'season': '2016',
#     'goals': '2',
#     'shots': '18',
#     'xG': '3.0252832546830177',
#     'assists': '1',
#     'key_passes': '26',
#     'xA': '3.2236178275197744',
#     'npg': '2',
#     'npxG': '3.0252832546830177'},
#    'shotSixYardBox': {'shotZones': 'shotSixYardBox',
#     'season': '2016',
#     'goals': '1',
#     'shots': '3',
#     'xG': '1.634680986404419',
#     'assists': '1',
#     'key_passes': '3',
#     'xA': '0.6931197866797447',
#     'npg': '1',
#     'npxG': '1.634680986404419'}},
#   '2019': {'shotOboxTotal': {'shotZones': 'shotOboxTotal',
#     'season': '2019',
#     'goals': '3',
#     'shots': '29',
#     'xG': '1.0858101909980178',
#     'assists': '2',
#     'key_passes': '8',
#     'xA': '0.21708429511636496',
#     'npg': '3',
#     'npxG': '1.0858101909980178'},
#    'shotPenaltyArea': {'shotZones': 'shotPenaltyArea',
#     'season': '2019',
#     'goals': '5',
#     'shots': '15',
#     'xG': '4.900269981473684',
#     'assists': '5',
#     'key_passes': '22',
#     'xA': '2.5379145834594965',
#     'npg': '1',
#     'npxG': '1.8556309305131435'}},
#   '2020': {'shotOboxTotal': {'shotZones': 'shotOboxTotal',
#     'season': '2020',
#     'goals': '1',
#     'shots': '73',
#     'xG': '2.65054586250335',
#     'assists': '3',
#     'key_passes': '27',
#     'xA': '0.7594643598422408',
#     'npg': '1',
#     'npxG': '2.65054586250335'},
#    'shotPenaltyArea': {'shotZones': 'shotPenaltyArea',
#     'season': '2020',
#     'goals': '17',
#     'shots': '46',
#     'xG': '12.592288728803396',
#     'assists': '7',
#     'key_passes': '61',
#     'xA': '7.793033797293901',
#     'npg': '8',
#     'npxG': '4.9806725941598415'},
#    'shotSixYardBox': {'shotZones': 'shotSixYardBox',
#     'season': '2020',
#     'goals': '0',
#     'shots': '2',
#     'xG': '0.7766219973564148',
#     'assists': '2',
#     'key_passes': '7',
#     'xA': '2.9224990233778954',
#     'npg': '0',
#     'npxG': '0.7766219973564148'}},
#   '2021': {'shotOboxTotal': {'shotZones': 'shotOboxTotal',
#     'season': '2021',
#     'goals': '2',
#     'shots': '52',
#     'xG': '1.8528814939782023',
#     'assists': '1',
#     'key_passes': '20',
#     'xA': '0.4822664996609092',
#     'npg': '2',
#     'npxG': '1.8528814939782023'},
#    'shotPenaltyArea': {'shotZones': 'shotPenaltyArea',
#     'season': '2021',
#     'goals': '8',
#     'shots': '36',
#     'xG': '7.394331978634',
#     'assists': '5',
#     'key_passes': '61',
#     'xA': '6.980392110534012',
#     'npg': '8',
#     'npxG': '5.871993945911527'},
#    'shotSixYardBox': {'shotZones': 'shotSixYardBox',
#     'season': '2021',
#     'goals': '0',
#     'shots': '1',
#     'xG': '0.03809469938278198',
#     'assists': '0',
#     'key_passes': '6',
#     'xA': '1.349193686619401',
#     'npg': '0',
#     'npxG': '0.03809469938278198'}},
#   '2022': {'shotOboxTotal': {'shotZones': 'shotOboxTotal',
#     'season': '2022',
#     'goals': '1',
#     'shots': '47',
#     'xG': '1.810519153252244',
#     'assists': '2',
#     'key_passes': '36',
#     'xA': '1.3159849112853408',
#     'npg': '1',
#     'npxG': '1.810519153252244'},
#    'shotPenaltyArea': {'shotZones': 'shotPenaltyArea',
#     'season': '2022',
#     'goals': '6',
#     'shots': '42',
#     'xG': '6.459120161831379',
#     'assists': '5',
#     'key_passes': '72',
#     'xA': '11.47144291549921',
#     'npg': '4',
#     'npxG': '4.93678230792284'},
#    'shotSixYardBox': {'shotZones': 'shotSixYardBox',
#     'season': '2022',
#     'goals': '1',
#     'shots': '3',
#     'xG': '1.1158170700073242',
#     'assists': '1',
#     'key_passes': '10',
#     'xA': '4.479282766580582',
#     'npg': '1',
#     'npxG': '1.1158170700073242'}},
#   '2023': {'shotOboxTotal': {'shotZones': 'shotOboxTotal',
#     'season': '2023',
#     'goals': '0',
#     'shots': '37',
#     'xG': '1.3581134844571352',
#     'assists': '0',
#     'key_passes': '21',
#     'xA': '0.7016497310250998',
#     'npg': '0',
#     'npxG': '1.3581134844571352'},
#    'shotPenaltyArea': {'shotZones': 'shotPenaltyArea',
#     'season': '2023',
#     'goals': '3',
#     'shots': '18',
#     'xG': '3.481888100504875',
#     'assists': '4',
#     'key_passes': '42',
#     'xA': '5.4880538349971175',
#     'npg': '2',
#     'npxG': '1.9595504254102707'},
#    'shotSixYardBox': {'shotZones': 'shotSixYardBox',
#     'season': '2023',
#     'goals': '0',
#     'shots': '1',
#     'xG': '0.6021673083305359',
#     'assists': '1',
#     'key_passes': '7',
#     'xA': '1.9105862136930227',
#     'npg': '0',
#     'npxG': '0.6021673083305359'}}},
#  'shotTypes': {'2014': {'RightFoot': {'shotTypes': 'RightFoot',
#     'season': '2014',
#     'goals': '2',
#     'shots': '35',
#     'xG': '2.061149836052209',
#     'assists': '0',
#     'key_passes': '11',
#     'xA': '1.0437040952965617',
#     'npg': '2',
#     'npxG': '2.061149836052209'},
#    'LeftFoot': {'shotTypes': 'LeftFoot',
#     'season': '2014',
#     'goals': '1',
#     'shots': '5',
#     'xG': '0.2689244970679283',
#     'assists': '1',
#     'key_passes': '7',
#     'xA': '0.8338164109736681',
#     'npg': '1',
#     'npxG': '0.2689244970679283'},
#    'Head': {'shotTypes': 'Head',
#     'season': '2014',
#     'goals': '0',
#     'shots': '1',
#     'xG': '0.3042669892311096',
#     'assists': '1',
#     'key_passes': '4',
#     'xA': '0.45443121157586575',
#     'npg': '0',
#     'npxG': '0.3042669892311096'}},
#   '2015': {'RightFoot': {'shotTypes': 'RightFoot',
#     'season': '2015',
#     'goals': '3',
#     'shots': '43',
#     'xG': '3.3818227211013436',
#     'assists': '0',
#     'key_passes': '15',
#     'xA': '0.9500565882772207',
#     'npg': '2',
#     'npxG': '1.8592246929183602'},
#    'LeftFoot': {'shotTypes': 'LeftFoot',
#     'season': '2015',
#     'goals': '0',
#     'shots': '6',
#     'xG': '0.2656033020466566',
#     'assists': '0',
#     'key_passes': '12',
#     'xA': '0.9540249770507216',
#     'npg': '0',
#     'npxG': '0.2656033020466566'},
#    'Head': {'shotTypes': 'Head',
#     'season': '2015',
#     'goals': '0',
#     'shots': '3',
#     'xG': '0.1459021009504795',
#     'assists': '4',
#     'key_passes': '17',
#     'xA': '1.8449210356920958',
#     'npg': '0',
#     'npxG': '0.1459021009504795'}},
#   '2016': {'RightFoot': {'shotTypes': 'RightFoot',
#     'season': '2016',
#     'goals': '5',
#     'shots': '53',
#     'xG': '4.176062846556306',
#     'assists': '0',
#     'key_passes': '22',
#     'xA': '0.7273081997409463',
#     'npg': '5',
#     'npxG': '4.176062846556306'},
#    'LeftFoot': {'shotTypes': 'LeftFoot',
#     'season': '2016',
#     'goals': '0',
#     'shots': '8',
#     'xG': '1.2941886764019728',
#     'assists': '1',
#     'key_passes': '17',
#     'xA': '2.225144441239536',
#     'npg': '0',
#     'npxG': '1.2941886764019728'},
#    'Head': {'shotTypes': 'Head',
#     'season': '2016',
#     'goals': '0',
#     'shots': '1',
#     'xG': '0.29132598638534546',
#     'assists': '1',
#     'key_passes': '13',
#     'xA': '1.5251424014568329',
#     'npg': '0',
#     'npxG': '0.29132598638534546'}},
#   '2019': {'RightFoot': {'shotTypes': 'RightFoot',
#     'season': '2019',
#     'goals': '8',
#     'shots': '37',
#     'xG': '5.325187577866018',
#     'assists': '4',
#     'key_passes': '13',
#     'xA': '1.3520659869536757',
#     'npg': '4',
#     'npxG': '2.280548526905477'},
#    'LeftFoot': {'shotTypes': 'LeftFoot',
#     'season': '2019',
#     'goals': '0',
#     'shots': '5',
#     'xG': '0.1988684982061386',
#     'assists': '2',
#     'key_passes': '10',
#     'xA': '0.9994571879506111',
#     'npg': '0',
#     'npxG': '0.1988684982061386'},
#    'Head': {'shotTypes': 'Head',
#     'season': '2019',
#     'goals': '0',
#     'shots': '2',
#     'xG': '0.46202409639954567',
#     'assists': '1',
#     'key_passes': '7',
#     'xA': '0.4034757036715746',
#     'npg': '0',
#     'npxG': '0.46202409639954567'}},
#   '2020': {'RightFoot': {'shotTypes': 'RightFoot',
#     'season': '2020',
#     'goals': '16',
#     'shots': '105',
#     'xG': '14.743183293379843',
#     'assists': '10',
#     'key_passes': '46',
#     'xA': '7.705555822700262',
#     'npg': '7',
#     'npxG': '7.1315671587362885'},
#    'LeftFoot': {'shotTypes': 'LeftFoot',
#     'season': '2020',
#     'goals': '1',
#     'shots': '11',
#     'xG': '0.5873842015862465',
#     'assists': '2',
#     'key_passes': '27',
#     'xA': '2.319493499584496',
#     'npg': '1',
#     'npxG': '0.5873842015862465'},
#    'Head': {'shotTypes': 'Head',
#     'season': '2020',
#     'goals': '1',
#     'shots': '5',
#     'xG': '0.6888890936970711',
#     'assists': '0',
#     'key_passes': '22',
#     'xA': '1.4499478582292795',
#     'npg': '1',
#     'npxG': '0.6888890936970711'}},
#   '2021': {'RightFoot': {'shotTypes': 'RightFoot',
#     'season': '2021',
#     'goals': '7',
#     'shots': '75',
#     'xG': '8.05363052431494',
#     'assists': '5',
#     'key_passes': '38',
#     'xA': '4.380449429154396',
#     'npg': '7',
#     'npxG': '6.531292491592467'},
#    'Head': {'shotTypes': 'Head',
#     'season': '2021',
#     'goals': '1',
#     'shots': '8',
#     'xG': '0.6698295343667269',
#     'assists': '0',
#     'key_passes': '17',
#     'xA': '1.3719352846965194',
#     'npg': '1',
#     'npxG': '0.6698295343667269'},
#    'LeftFoot': {'shotTypes': 'LeftFoot',
#     'season': '2021',
#     'goals': '2',
#     'shots': '6',
#     'xG': '0.5618481133133173',
#     'assists': '1',
#     'key_passes': '31',
#     'xA': '3.0194388842210174',
#     'npg': '2',
#     'npxG': '0.5618481133133173'},
#    'OtherBodyPart': {'shotTypes': 'OtherBodyPart',
#     'season': '2021',
#     'goals': '0',
#     'shots': '0',
#     'xG': '0',
#     'assists': '0',
#     'key_passes': '1',
#     'xA': '0.04002869874238968',
#     'npg': '0',
#     'npxG': '0'}},
#   '2022': {'RightFoot': {'shotTypes': 'RightFoot',
#     'season': '2022',
#     'goals': '8',
#     'shots': '73',
#     'xG': '8.125196631997824',
#     'assists': '5',
#     'key_passes': '51',
#     'xA': '7.224511770531535',
#     'npg': '6',
#     'npxG': '6.602858778089285'},
#    'LeftFoot': {'shotTypes': 'LeftFoot',
#     'season': '2022',
#     'goals': '0',
#     'shots': '11',
#     'xG': '0.4663883689790964',
#     'assists': '3',
#     'key_passes': '53',
#     'xA': '8.721979978494346',
#     'npg': '0',
#     'npxG': '0.4663883689790964'},
#    'Head': {'shotTypes': 'Head',
#     'season': '2022',
#     'goals': '0',
#     'shots': '8',
#     'xG': '0.793871384114027',
#     'assists': '0',
#     'key_passes': '14',
#     'xA': '1.3202188443392515',
#     'npg': '0',
#     'npxG': '0.793871384114027'}},
#   '2023': {'RightFoot': {'shotTypes': 'RightFoot',
#     'season': '2023',
#     'goals': '3',
#     'shots': '46',
#     'xG': '4.6054677516222',
#     'assists': '3',
#     'key_passes': '26',
#     'xA': '2.8050572015345097',
#     'npg': '2',
#     'npxG': '3.0831300765275955'},
#    'LeftFoot': {'shotTypes': 'LeftFoot',
#     'season': '2023',
#     'goals': '0',
#     'shots': '8',
#     'xG': '0.3567918185144663',
#     'assists': '1',
#     'key_passes': '24',
#     'xA': '2.0914916526526213',
#     'npg': '0',
#     'npxG': '0.3567918185144663'},
#    'Head': {'shotTypes': 'Head',
#     'season': '2023',
#     'goals': '0',
#     'shots': '2',
#     'xG': '0.47990932315588',
#     'assists': '1',
#     'key_passes': '20',
#     'xA': '3.203740925528109',
#     'npg': '0',
#     'npxG': '0.47990932315588'}}}}

# %%
season_data = pd.json_normalize(data['season'])
season_data
# Out:
#   position games goals shots  time                  xG assists  \
# 0       MC    23     3    56  2070   5.442168924026191       5
# 1       MC    37     8    92  3326   9.385456696152687       8
# 2      AMC    36    10    89  3135   9.285304862074554       6
# 3      AMC    37    18   121  3117  16.019450719468296      12
# 4      AMC    14     8    44  1211    5.98607742600143       7
# 5      Sub    33     5    62  1736   5.761577281169593       2
# 6       MC    31     3    52  2116    3.79332700651139       4
# 7      Sub    31     3    41  1605   2.634341513738036       2
#
#                    xA key_passes season               team yellow red npg  \
# 0   8.100289855152369         70   2023  Manchester United      7   0   2
# 1  17.266709440387785        118   2022  Manchester United      6   0   6
# 2   8.811852657236159         88   2021  Manchester United     10   0  10
# 3  11.474997889250517         95   2020  Manchester United      6   0   9
# 4  2.7549998983740807         30   2019  Manchester United      2   0   4
# 5  4.4775946363806725         52   2016          Sampdoria      2   0   5
# 6  3.7490005446597934         44   2015            Udinese      7   1   2
# 7   2.331952504813671         22   2014            Udinese      5   0   3
#
#                  npxG             xGChain           xGBuildup
# 0  3.9198311595246196  13.199519656598568   7.296374291181564
# 1   7.863118812441826  35.418096881359816  17.724953144788742
# 2   7.762967492453754   22.98672279715538   11.14225958287716
# 3   8.407837779261172   26.91141940653324  11.932286506518722
# 4  2.9414413776248693   8.513753656297922   4.864240288734436
# 5   5.761577281169593  11.588001352734864  3.9690468413755298
# 6  2.2707290379330516   8.635709737427533   4.768451112322509
# 7   2.634341513738036   5.787391685880721  2.2256615795195103

# %%
position_data = pd.json_normalize(data['position'])
position_data.T
# Out:
#                                      0
# 2023.AMC.position                  AMC
# 2023.AMC.games                      19
# 2023.AMC.goals                       2
# 2023.AMC.shots                      45
# 2023.AMC.time                     1710
# ...                                ...
# 2014.ML.red                          0
# 2014.ML.npg                          0
# 2014.ML.npxG        0.2823210060596466
# 2014.ML.xGChain     1.0028970018029213
# 2014.ML.xGBuildup  0.32544879615306854
#
# [448 rows x 1 columns]

# %%
position_2023 = pd.json_normalize(data['position']['2023'])
position_2023.T
# Out:
#                                    0
# AMC.position                     AMC
# AMC.games                         19
# AMC.goals                          2
# AMC.shots                         45
# AMC.time                        1710
# AMC.xG             4.792987785302103
# AMC.assists                        5
# AMC.xA             7.526210632175207
# AMC.key_passes                    62
# AMC.season                      2023
# AMC.yellow                         6
# AMC.red                            0
# AMC.npg                            1
# AMC.npxG           3.270650020800531
# AMC.xGChain       10.732586733996868
# AMC.xGBuildup      5.740406826138496
# AMR.position                     AMR
# AMR.games                          3
# AMR.goals                          1
# AMR.shots                         10
# AMR.time                         270
# AMR.xG             0.632633626461029
# AMR.assists                        0
# AMR.xA            0.2651810422539711
# AMR.key_passes                     5
# AMR.season                      2023
# AMR.yellow                         1
# AMR.red                            0
# AMR.npg                            1
# AMR.npxG           0.632633626461029
# AMR.xGChain       1.3941647112369537
# AMR.xGBuildup      0.706288531422615
# MC.position                       MC
# MC.games                           1
# MC.goals                           0
# MC.shots                           1
# MC.time                           90
# MC.xG           0.016547512263059616
# MC.assists                         0
# MC.xA             0.3088981807231903
# MC.key_passes                      3
# MC.season                       2023
# MC.yellow                          0
# MC.red                             0
# MC.npg                             0
# MC.npxG         0.016547512263059616
# MC.xGChain         1.072768211364746
# MC.xGBuildup      0.8496789336204529

# %%
position_2023_AMC = pd.json_normalize(data['position']['2023']['AMC'])
position_2023_AMR = pd.json_normalize(data['position']['2023']['AMR'])
position_2023_MC = pd.json_normalize(data['position']['2023']['MC'])
positions_2023 = pd.concat([position_2023_AMC,position_2023_AMR,
                            position_2023_MC])
positions_2023[['games','goals','shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG','xGChain',
                'xGBuildup']] = positions_2023[['games','goals',
                'shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG',
                'xGChain','xGBuildup']].apply(pd.to_numeric)
positions_2023.loc['total']= positions_2023.sum()
positions_2023.loc[positions_2023.index[-1], 'position'] = ''
positions_2023.loc[positions_2023.index[-1], 'season'] = '2023'
positions_2023
#on the website/page, there's also Sh90 (shots per 90), KP90(key passes per90),
#xG90 (xG per 90), xA90 (xA per 90), but not in the raw json data -> it could
#calculated by getting the 90s from the 'time' column (value/90) and creating
#new columns for each metric where we divide the total values by the 90s
#they also show next to expected metrics the difference compared to actual 
#values (goals, assists), but I'm not replicating it for now
# Out:
#       position  games  goals  shots  time        xG  assists        xA  \
# 0          AMC     19      2     45  1710  4.792988        5  7.526211
# 0          AMR      3      1     10   270  0.632634        0  0.265181
# 0           MC      1      0      1    90  0.016548        0  0.308898
# total              23      3     56  2070  5.442169        5  8.100290
#
#        key_passes season  yellow  red  npg      npxG    xGChain  xGBuildup
# 0              62   2023       6    0    1  3.270650  10.732587   5.740407
# 0               5   2023       1    0    1  0.632634   1.394165   0.706289
# 0               3   2023       0    0    0  0.016548   1.072768   0.849679
# total          70   2023       7    0    2  3.919831  13.199520   7.296374

# %%
position_2022_AMC = pd.json_normalize(data['position']['2022']['AMC'])
position_2022_AMR = pd.json_normalize(data['position']['2022']['AMR'])
position_2022_AML = pd.json_normalize(data['position']['2022']['AML'])
position_2022_MC = pd.json_normalize(data['position']['2022']['MC'])
position_2022_DMC = pd.json_normalize(data['position']['2022']['DMC'])
position_2022_MR = pd.json_normalize(data['position']['2022']['MR'])
positions_2022 = pd.concat([position_2022_AMC,position_2022_AMR,
                            position_2022_AML,position_2022_DMC,
                            position_2022_MC,position_2022_MR])
positions_2022[['games','goals','shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG','xGChain',
                'xGBuildup']] = positions_2022[['games','goals',
                'shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG',
                'xGChain','xGBuildup']].apply(pd.to_numeric)
position_2021_AMC = pd.json_normalize(data['position']['2021']['AMC'])
position_2021_AML = pd.json_normalize(data['position']['2021']['AML'])
position_2021_MC = pd.json_normalize(data['position']['2021']['MC'])
position_2021_Sub = pd.json_normalize(data['position']['2021']['Sub'])
position_2021_FW = pd.json_normalize(data['position']['2021']['FW'])
positions_2021 = pd.concat([position_2021_AMC,position_2021_AML,
                            position_2021_MC,position_2021_Sub,
                            position_2021_FW])
positions_2021[['games','goals','shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG','xGChain',
                'xGBuildup']] = positions_2021[['games','goals',
                'shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG',
                'xGChain','xGBuildup']].apply(pd.to_numeric)
position_2020_AMC = pd.json_normalize(data['position']['2020']['AMC'])
position_2020_Sub = pd.json_normalize(data['position']['2020']['Sub'])
positions_2020 = pd.concat([position_2020_AMC,position_2020_Sub])
positions_2020[['games','goals','shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG','xGChain',
                'xGBuildup']] = positions_2020[['games','goals',
                'shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG',
                'xGChain','xGBuildup']].apply(pd.to_numeric)
positions_2019 = pd.json_normalize(data['position']['2019']['AMC'])
positions_2019[['games','goals','shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG','xGChain',
                'xGBuildup']] = positions_2019[['games','goals',
                'shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG',
                'xGChain','xGBuildup']].apply(pd.to_numeric)
position_2016_AMC = pd.json_normalize(data['position']['2016']['AMC'])
position_2016_Sub = pd.json_normalize(data['position']['2016']['Sub'])
positions_2016 = pd.concat([position_2016_AMC,position_2016_Sub])
positions_2016[['games','goals','shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG','xGChain',
                'xGBuildup']] = positions_2016[['games','goals',
                'shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG',
                'xGChain','xGBuildup']].apply(pd.to_numeric)
position_2015_AMC = pd.json_normalize(data['position']['2015']['AMC'])
position_2015_MC = pd.json_normalize(data['position']['2015']['MC'])
position_2015_Sub = pd.json_normalize(data['position']['2015']['Sub'])
position_2015_FWL = pd.json_normalize(data['position']['2015']['FWL'])
position_2015_FWR = pd.json_normalize(data['position']['2015']['FWR'])
positions_2015 = pd.concat([position_2015_AMC,position_2015_MC,
                            position_2015_Sub,position_2015_FWL,
                            position_2015_FWR])
positions_2015[['games','goals','shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG','xGChain',
                'xGBuildup']] = positions_2015[['games','goals',
                'shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG',
                'xGChain','xGBuildup']].apply(pd.to_numeric)
position_2014_AMC = pd.json_normalize(data['position']['2014']['AMC'])
position_2014_MC = pd.json_normalize(data['position']['2014']['MC'])
position_2014_Sub = pd.json_normalize(data['position']['2014']['Sub'])
position_2014_ML = pd.json_normalize(data['position']['2014']['ML'])
positions_2014 = pd.concat([position_2014_AMC,position_2014_MC,
                            position_2014_Sub,position_2014_ML])
positions_2014[['games','goals','shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG','xGChain',
                'xGBuildup']] = positions_2014[['games','goals',
                'shots','time','xG','assists','xA',
                'key_passes','yellow','red','npg','npxG',
                'xGChain','xGBuildup']].apply(pd.to_numeric)

# %%
positions_all = pd.concat([positions_2014,positions_2015,positions_2016,positions_2019,
                           positions_2020,positions_2021,positions_2022,positions_2023])
positions_all = positions_all.groupby('position').sum()
positions_all.drop('AMCAMRMC',inplace=True)
positions_all.drop(['season'],axis=1,inplace=True)
positions_all.loc['total']= positions_all.sum()
positions_all.loc[positions_all.index[-1], 'position'] = ''
positions_all
# Out:
#           games  goals  shots     time         xG  assists         xA  \
# position
# AMC       156.0   46.0  407.0  13188.0  45.399563     37.0  44.252222
# AML         5.0    1.0   20.0    450.0   2.042482      0.0   1.484221
# AMR         6.0    2.0   18.0    540.0   1.328287      3.0   3.652121
# DMC         2.0    0.0    5.0    180.0   0.443033      0.0   0.976870
# FW          2.0    0.0    5.0    180.0   0.204547      0.0   0.117889
# FWL         1.0    1.0    3.0     90.0   0.373913      0.0   0.132882
# FWR         2.0    0.0    2.0    171.0   0.028145      0.0   0.152807
# MC         28.0    3.0   56.0   2336.0   3.812721      5.0   4.827663
# ML          3.0    0.0    2.0    196.0   0.282321      0.0   0.395127
# MR          1.0    1.0    2.0     90.0   0.386674      0.0   0.327627
# Sub        36.0    4.0   37.0    895.0   4.006018      1.0   2.647968
# total     242.0   58.0  557.0  18316.0  58.307704     46.0  58.967397
#
#           key_passes  yellow  red   npg       npxG     xGChain  xGBuildup  \
# position
# AMC            389.0    34.0  0.0  30.0  30.176301   98.147696  48.504546
# AML             11.0     0.0  0.0   1.0   2.042482    3.942079   1.622461
# AMR             19.0     1.0  0.0   2.0   1.328287    7.068355   2.471354
# DMC              9.0     1.0  0.0   0.0   0.443033    2.031524   1.457587
# FW               2.0     0.0  0.0   0.0   0.204547    0.498258   0.268235
# FWL              4.0     0.0  0.0   1.0   0.373913    0.484263   0.051761
# FWR              3.0     0.0  0.0   0.0   0.028145    0.580428   0.447162
# MC              50.0     7.0  1.0   2.0   2.290123    9.458679   4.708360
# ML               1.0     1.0  0.0   0.0   0.282321    1.002897   0.325449
# MR               1.0     0.0  0.0   1.0   0.386674    0.906405   0.192104
# Sub             30.0     1.0  0.0   4.0   4.006018    8.920033   3.874254
# total          519.0    45.0  1.0  41.0  41.561844  133.040615  63.923273
#
#          position
# position
# AMC           NaN
# AML           NaN
# AMR           NaN
# DMC           NaN
# FW            NaN
# FWL           NaN
# FWR           NaN
# MC            NaN
# ML            NaN
# MR            NaN
# Sub           NaN
# total

# %%
df_position_table = pd.DataFrame(data['position'])
df_position_table
# Out:
#                                                   2023  \
# AMC  {'position': 'AMC', 'games': '19', 'goals': '2...
# AMR  {'position': 'AMR', 'games': '3', 'goals': '1'...
# MC   {'position': 'MC', 'games': '1', 'goals': '0',...
# AML                                                NaN
# DMC                                                NaN
# MR                                                 NaN
# FW                                                 NaN
# Sub                                                NaN
# FWR                                                NaN
# FWL                                                NaN
# ML                                                 NaN
#
#                                                   2022  \
# AMC  {'position': 'AMC', 'games': '26', 'goals': '6...
# AMR  {'position': 'AMR', 'games': '3', 'goals': '1'...
# MC   {'position': 'MC', 'games': '3', 'goals': '0',...
# AML  {'position': 'AML', 'games': '2', 'goals': '0'...
# DMC  {'position': 'DMC', 'games': '2', 'goals': '0'...
# MR   {'position': 'MR', 'games': '1', 'goals': '1',...
# FW                                                 NaN
# Sub                                                NaN
# FWR                                                NaN
# FWL                                                NaN
# ML                                                 NaN
#
#                                                   2021  \
# AMC  {'position': 'AMC', 'games': '28', 'goals': '9...
# AMR                                                NaN
# MC   {'position': 'MC', 'games': '2', 'goals': '0',...
# AML  {'position': 'AML', 'games': '3', 'goals': '1'...
# DMC                                                NaN
# MR                                                 NaN
# FW   {'position': 'FW', 'games': '2', 'goals': '0',...
# Sub  {'position': 'Sub', 'games': '1', 'goals': '0'...
# FWR                                                NaN
# FWL                                                NaN
# ML                                                 NaN
#
#                                                   2020  \
# AMC  {'position': 'AMC', 'games': '35', 'goals': '1...
# AMR                                                NaN
# MC                                                 NaN
# AML                                                NaN
# DMC                                                NaN
# MR                                                 NaN
# FW                                                 NaN
# Sub  {'position': 'Sub', 'games': '2', 'goals': '0'...
# FWR                                                NaN
# FWL                                                NaN
# ML                                                 NaN
#
#                                                   2019  \
# AMC  {'position': 'AMC', 'games': '14', 'goals': '8...
# AMR                                                NaN
# MC                                                 NaN
# AML                                                NaN
# DMC                                                NaN
# MR                                                 NaN
# FW                                                 NaN
# Sub                                                NaN
# FWR                                                NaN
# FWL                                                NaN
# ML                                                 NaN
#
#                                                   2016  \
# AMC  {'position': 'AMC', 'games': '22', 'goals': '2...
# AMR                                                NaN
# MC                                                 NaN
# AML                                                NaN
# DMC                                                NaN
# MR                                                 NaN
# FW                                                 NaN
# Sub  {'position': 'Sub', 'games': '11', 'goals': '3...
# FWR                                                NaN
# FWL                                                NaN
# ML                                                 NaN
#
#                                                   2015  \
# AMC  {'position': 'AMC', 'games': '3', 'goals': '0'...
# AMR                                                NaN
# MC   {'position': 'MC', 'games': '18', 'goals': '2'...
# AML                                                NaN
# DMC                                                NaN
# MR                                                 NaN
# FW                                                 NaN
# Sub  {'position': 'Sub', 'games': '7', 'goals': '0'...
# FWR  {'position': 'FWR', 'games': '2', 'goals': '0'...
# FWL  {'position': 'FWL', 'games': '1', 'goals': '1'...
# ML                                                 NaN
#
#                                                   2014
# AMC  {'position': 'AMC', 'games': '9', 'goals': '1'...
# AMR                                                NaN
# MC   {'position': 'MC', 'games': '4', 'goals': '1',...
# AML                                                NaN
# DMC                                                NaN
# MR                                                 NaN
# FW                                                 NaN
# Sub  {'position': 'Sub', 'games': '15', 'goals': '1...
# FWR                                                NaN
# FWL                                                NaN
# ML   {'position': 'ML', 'games': '3', 'goals': '0',...

# %%
df_position_table['2022'].apply(pd.Series)
# Out:
#     position games goals shots  time                   xG assists  \
# AMC      AMC    26     6    67  2336    7.438450904563069       5
# AMR      AMR     3     1     8   270   0.6956530064344406       3
# MC        MC     3     0     5   270  0.23019780963659286       0
# AML      AML     2     0     5   180   0.1914479210972786       0
# DMC      DMC     2     0     5   180   0.4430330079048872       0
# MR        MR     1     1     2    90  0.38667404651641846       0
# FW       NaN   NaN   NaN   NaN   NaN                  NaN     NaN
# Sub      NaN   NaN   NaN   NaN   NaN                  NaN     NaN
# FWR      NaN   NaN   NaN   NaN   NaN                  NaN     NaN
# FWL      NaN   NaN   NaN   NaN   NaN                  NaN     NaN
# ML       NaN   NaN   NaN   NaN   NaN                  NaN     NaN
#
#                       xA key_passes season yellow  red  npg  \
# AMC   10.198626049794257         79   2022      5    0    4
# AMR   3.3869400024414062         14   2022      0    0    1
# MC    1.5511826574802399          9   2022      0    0    0
# AML   0.8254640996456146          6   2022      0    0    0
# DMC    0.976869985461235          9   2022      1    0    0
# MR   0.32762664556503296          1   2022      0    0    1
# FW                   NaN        NaN    NaN    NaN  NaN  NaN
# Sub                  NaN        NaN    NaN    NaN  NaN  NaN
# FWR                  NaN        NaN    NaN    NaN  NaN  NaN
# FWL                  NaN        NaN    NaN    NaN  NaN  NaN
# ML                   NaN        NaN    NaN    NaN  NaN  NaN
#
#                     npxG             xGChain            xGBuildup   0
# AMC    5.916113020852208  23.945894669741392   13.256883010268211 NaN
# AMR   0.6956530064344406   5.674190044403076   1.7650649845600128 NaN
# MC   0.23019780963659286  1.8387940227985382   0.5520040616393089 NaN
# AML   0.1914479210972786  1.0212895572185516   0.5013101175427437 NaN
# DMC   0.4430330079048872    2.03152397274971   1.4575870335102081 NaN
# MR   0.38667404651641846  0.9064046144485474  0.19210393726825714 NaN
# FW                   NaN                 NaN                  NaN NaN
# Sub                  NaN                 NaN                  NaN NaN
# FWR                  NaN                 NaN                  NaN NaN
# FWL                  NaN                 NaN                  NaN NaN
# ML                   NaN                 NaN                  NaN NaN

# %%
pd.DataFrame(data['position']['2021']).T
# Out:
#     position games goals shots  time                   xG assists  \
# AMC      AMC    28     9    63  2476    6.694973829202354       6
# AML      AML     3     1    15   270   1.8510341122746468       0
# MC        MC     2     0     4   180  0.11685980297625065       0
# FW        FW     2     0     5   180   0.2045471053570509       0
# Sub      Sub     1     0     2    29   0.4178900122642517       0
#
#                       xA key_passes season yellow red npg  \
# AMC    7.842104258947074         79   2021     10   0   9
# AML   0.6587570011615753          5   2021      0   0   1
# MC   0.09007179737091064          1   2021      0   0   0
# FW   0.11788859777152538          2   2021      0   0   0
# Sub  0.10303100198507309          1   2021      0   0   0
#
#                     npxG             xGChain            xGBuildup
# AMC    5.172636459581554   18.25581879168749     9.00605158507824
# AML   1.8510341122746468  2.9207890033721924   1.1211509704589844
# MC   0.11685980297625065  0.7768729999661446    0.641677625477314
# FW    0.2045471053570509  0.4982580095529556   0.2682354003190994
# Sub   0.4178900122642517  0.5349839925765991  0.10514400154352188

# %%
pd.DataFrame(data['situation']['2022']).T
# Out:
#                      situation season goals shots                  xG assists  \
# OpenPlay              OpenPlay   2022     6    79   7.253958882763982       8
# DirectFreekick  DirectFreekick   2022     0     6  0.4032558798789978       0
# FromCorner          FromCorner   2022     0     5  0.2059037685394287       0
# Penalty                Penalty   2022     2     2  1.5223378539085388       0
# SetPiece              SetPiece   2022     0     0                   0       0
#
#                key_passes                  xA npg                npxG  time
# OpenPlay               88  14.336424613371491   6   7.253958882763982  3326
# DirectFreekick          0                   0   0  0.4032558798789978  3326
# FromCorner             27  2.0791266644373536   0  0.2059037685394287  3326
# Penalty                 0                   0   0                   0  3326
# SetPiece                3  0.8511593155562878   0                   0  3326

# %%
pd.DataFrame(data['shotZones']['2022']).T
# Out:
#                        shotZones season goals shots                  xG  \
# shotOboxTotal      shotOboxTotal   2022     1    47   1.810519153252244
# shotPenaltyArea  shotPenaltyArea   2022     6    42   6.459120161831379
# shotSixYardBox    shotSixYardBox   2022     1     3  1.1158170700073242
#
#                 assists key_passes                  xA npg                npxG
# shotOboxTotal         2         36  1.3159849112853408   1   1.810519153252244
# shotPenaltyArea       5         72   11.47144291549921   4    4.93678230792284
# shotSixYardBox        1         10   4.479282766580582   1  1.1158170700073242

# %%
pd.DataFrame(data['shotTypes']['2022']).T
# Out:
#            shotTypes season goals shots                  xG assists  \
# RightFoot  RightFoot   2022     8    73   8.125196631997824       5
# LeftFoot    LeftFoot   2022     0    11  0.4663883689790964       3
# Head            Head   2022     0     8   0.793871384114027       0
#
#           key_passes                  xA npg                npxG
# RightFoot         51   7.224511770531535   6   6.602858778089285
# LeftFoot          53   8.721979978494346   0  0.4663883689790964
# Head              14  1.3202188443392515   0   0.793871384114027

# %%
openplay_2022 = pd.json_normalize(data['situation']['2022']['OpenPlay'])
freekick_2022 = pd.json_normalize(data['situation']['2022']['DirectFreekick'])
corner_2022 = pd.json_normalize(data['situation']['2022']['FromCorner'])
penalty_2022 = pd.json_normalize(data['situation']['2022']['Penalty'])
setpiece_2022 = pd.json_normalize(data['situation']['2022']['SetPiece'])
situation_2022 = pd.concat([openplay_2022,freekick_2022,
                            corner_2022,penalty_2022,
                            setpiece_2022,setpiece_2022])
situation_2022[['goals','shots','xG','assists','xA',
                'key_passes','npg','npxG']] = situation_2022[['goals','shots','xG','assists','xA',
                'key_passes','npg','npxG']].apply(pd.to_numeric)
situation_2022.loc['total']= situation_2022.sum()
situation_2022.loc[situation_2022.index[-1], 'situation'] = ''
situation_2022.loc[situation_2022.index[-1], 'time'] = ''
situation_2022.loc[situation_2022.index[-1], 'season'] = '2022'
situation_2022
# Out:
#             situation season  goals  shots        xG  assists  key_passes  \
# 0            OpenPlay   2022      6     79  7.253959        8          88
# 0      DirectFreekick   2022      0      6  0.403256        0           0
# 0          FromCorner   2022      0      5  0.205904        0          27
# 0             Penalty   2022      2      2  1.522338        0           0
# 0            SetPiece   2022      0      0  0.000000        0           3
# 0            SetPiece   2022      0      0  0.000000        0           3
# total                   2022      8     92  9.385456        8         121
#
#               xA  npg      npxG  time
# 0      14.336425    6  7.253959  3326
# 0       0.000000    0  0.403256  3326
# 0       2.079127    0  0.205904  3326
# 0       0.000000    0  0.000000  3326
# 0       0.851159    0  0.000000  3326
# 0       0.851159    0  0.000000  3326
# total  18.117870    6  7.863119

# %%
openplay_2023 = pd.json_normalize(data['situation']['2023']['OpenPlay'])
freekick_2023 = pd.json_normalize(data['situation']['2023']['DirectFreekick'])
corner_2023 = pd.json_normalize(data['situation']['2023']['FromCorner'])
penalty_2023 = pd.json_normalize(data['situation']['2023']['Penalty'])
setpiece_2023 = pd.json_normalize(data['situation']['2023']['SetPiece'])
situation_2023 = pd.concat([openplay_2023,freekick_2023,
                            corner_2023,penalty_2023,
                            setpiece_2023,setpiece_2023])
openplay_2022 = pd.json_normalize(data['situation']['2022']['OpenPlay'])
freekick_2022 = pd.json_normalize(data['situation']['2022']['DirectFreekick'])
corner_2022 = pd.json_normalize(data['situation']['2022']['FromCorner'])
penalty_2022 = pd.json_normalize(data['situation']['2022']['Penalty'])
setpiece_2022 = pd.json_normalize(data['situation']['2022']['SetPiece'])
situation_2022 = pd.concat([openplay_2022,freekick_2022,
                            corner_2022,penalty_2022,
                            setpiece_2022,setpiece_2022])
openplay_2021 = pd.json_normalize(data['situation']['2021']['OpenPlay'])
freekick_2021 = pd.json_normalize(data['situation']['2021']['DirectFreekick'])
corner_2021 = pd.json_normalize(data['situation']['2021']['FromCorner'])
penalty_2021 = pd.json_normalize(data['situation']['2021']['Penalty'])
setpiece_2021 = pd.json_normalize(data['situation']['2021']['SetPiece'])
situation_2021 = pd.concat([openplay_2021,freekick_2021,
                            corner_2021,penalty_2021,
                            setpiece_2021,setpiece_2021])

openplay_2020 = pd.json_normalize(data['situation']['2020']['OpenPlay'])
freekick_2020 = pd.json_normalize(data['situation']['2020']['DirectFreekick'])
corner_2020 = pd.json_normalize(data['situation']['2020']['FromCorner'])
penalty_2020 = pd.json_normalize(data['situation']['2020']['Penalty'])
setpiece_2020 = pd.json_normalize(data['situation']['2020']['SetPiece'])
situation_2020 = pd.concat([openplay_2020,freekick_2020,
                            corner_2020,penalty_2020,
                            setpiece_2020,setpiece_2020])

openplay_2019 = pd.json_normalize(data['situation']['2019']['OpenPlay'])
freekick_2019 = pd.json_normalize(data['situation']['2019']['DirectFreekick'])
corner_2019 = pd.json_normalize(data['situation']['2019']['FromCorner'])
penalty_2019 = pd.json_normalize(data['situation']['2019']['Penalty'])
setpiece_2019 = pd.json_normalize(data['situation']['2019']['SetPiece'])
situation_2019 = pd.concat([openplay_2019,freekick_2019,
                            corner_2019,penalty_2019,
                            setpiece_2019,setpiece_2019])

openplay_2016 = pd.json_normalize(data['situation']['2016']['OpenPlay'])
freekick_2016 = pd.json_normalize(data['situation']['2016']['DirectFreekick'])
corner_2016 = pd.json_normalize(data['situation']['2016']['FromCorner'])
setpiece_2016 = pd.json_normalize(data['situation']['2016']['SetPiece'])
situation_2016 = pd.concat([openplay_2016,freekick_2016,
                            corner_2016,
                            setpiece_2016,setpiece_2016])
openplay_2015 = pd.json_normalize(data['situation']['2015']['OpenPlay'])
freekick_2015 = pd.json_normalize(data['situation']['2015']['DirectFreekick'])
corner_2015 = pd.json_normalize(data['situation']['2015']['FromCorner'])
penalty_2015 = pd.json_normalize(data['situation']['2015']['Penalty'])
setpiece_2015 = pd.json_normalize(data['situation']['2015']['SetPiece'])
situation_2015 = pd.concat([openplay_2015,freekick_2015,
                            corner_2015,penalty_2015,
                            setpiece_2015,setpiece_2015])
openplay_2014 = pd.json_normalize(data['situation']['2014']['OpenPlay'])
freekick_2014 = pd.json_normalize(data['situation']['2014']['DirectFreekick'])
corner_2014 = pd.json_normalize(data['situation']['2014']['FromCorner'])
situation_2014 = pd.concat([openplay_2014,freekick_2014,
                            corner_2014])


situation_all = pd.concat([situation_2014,situation_2015,situation_2016,situation_2019,
                           situation_2020,situation_2021,situation_2022,situation_2023])
situation_all[['goals','shots','xG','assists','xA',
                'key_passes','npg','npxG']] = situation_all[['goals','shots','xG','assists','xA',
                'key_passes','npg','npxG']].apply(pd.to_numeric)
situation_all.drop(['season'],axis=1,inplace=True)
situation_all.drop(['time'],axis=1,inplace=True)
situation_all = situation_all.groupby('situation').sum()
situation_all.loc['total']= situation_all.sum()
situation_all
# Out:
#                 goals  shots         xG  assists  key_passes         xA   npg  \
# situation
# DirectFreekick    1.0   56.0   3.610480      0.0         0.0   0.000000   1.0
# FromCorner        0.0   44.0   1.110408      5.0       108.0   8.212672   0.0
# OpenPlay         38.0  428.0  36.042932     39.0       384.0  46.558019  38.0
# Penalty          17.0   22.0  16.745867      0.0         0.0   0.000000   0.0
# SetPiece          4.0   14.0   1.596062      4.0        52.0   8.393415   4.0
# total            60.0  564.0  59.105748     48.0       544.0  63.164105  43.0
#
#                      npxG
# situation
# DirectFreekick   3.610480
# FromCorner       1.110408
# OpenPlay        36.042932
# Penalty          0.000000
# SetPiece         1.596062
# total           42.359881

# %%
shotPenaltyArea_2022 = pd.json_normalize(data['shotZones']['2022']['shotPenaltyArea'])
shotOboxTotal_2022 = pd.json_normalize(data['shotZones']['2022']['shotOboxTotal'])
shotSixYardBox_2022 = pd.json_normalize(data['shotZones']['2022']['shotSixYardBox'])
shotzones_2022 = pd.concat([shotPenaltyArea_2022,shotOboxTotal_2022,
                            shotSixYardBox_2022])
shotzones_2022[['goals','shots','xG','assists','xA',
                'key_passes','npg','npxG']] = shotzones_2022[['goals','shots','xG','assists','xA',
                'key_passes','npg','npxG']].apply(pd.to_numeric)
shotzones_2022.loc['total']= shotzones_2022.sum()
shotzones_2022.loc[shotzones_2022.index[-1], 'shotZones'] = ''

shotzones_2022.loc[shotzones_2022.index[-1], 'season'] = '2022'
shotzones_2022
#on the website there are also xG/Sh and xA/KP columns -> these could be calculated from this data...
# Out:
#              shotZones season  goals  shots        xG  assists  key_passes  \
# 0      shotPenaltyArea   2022      6     42  6.459120        5          72
# 0        shotOboxTotal   2022      1     47  1.810519        2          36
# 0       shotSixYardBox   2022      1      3  1.115817        1          10
# total                    2022      8     92  9.385456        8         118
#
#               xA  npg      npxG
# 0      11.471443    4  4.936782
# 0       1.315985    1  1.810519
# 0       4.479283    1  1.115817
# total  17.266711    6  7.863119

# %%
shotPenaltyArea_2023 = pd.json_normalize(data['shotZones']['2023']['shotPenaltyArea'])
shotOboxTotal_2023 = pd.json_normalize(data['shotZones']['2023']['shotOboxTotal'])
shotSixYardBox_2023 = pd.json_normalize(data['shotZones']['2023']['shotSixYardBox'])
shotzones_2023 = pd.concat([shotPenaltyArea_2023,shotOboxTotal_2023,
                            shotSixYardBox_2023])

shotPenaltyArea_2022 = pd.json_normalize(data['shotZones']['2022']['shotPenaltyArea'])
shotOboxTotal_2022 = pd.json_normalize(data['shotZones']['2022']['shotOboxTotal'])
shotSixYardBox_2022 = pd.json_normalize(data['shotZones']['2022']['shotSixYardBox'])
shotzones_2022 = pd.concat([shotPenaltyArea_2022,shotOboxTotal_2022,
                            shotSixYardBox_2022])

shotPenaltyArea_2021 = pd.json_normalize(data['shotZones']['2021']['shotPenaltyArea'])
shotOboxTotal_2021 = pd.json_normalize(data['shotZones']['2021']['shotOboxTotal'])
shotSixYardBox_2021 = pd.json_normalize(data['shotZones']['2021']['shotSixYardBox'])
shotzones_2021 = pd.concat([shotPenaltyArea_2021,shotOboxTotal_2021,
                            shotSixYardBox_2021])

shotPenaltyArea_2020 = pd.json_normalize(data['shotZones']['2020']['shotPenaltyArea'])
shotOboxTotal_2020 = pd.json_normalize(data['shotZones']['2020']['shotOboxTotal'])
shotSixYardBox_2020 = pd.json_normalize(data['shotZones']['2020']['shotSixYardBox'])
shotzones_2020 = pd.concat([shotPenaltyArea_2020,shotOboxTotal_2020,
                            shotSixYardBox_2020])

shotPenaltyArea_2019 = pd.json_normalize(data['shotZones']['2019']['shotPenaltyArea'])
shotOboxTotal_2019 = pd.json_normalize(data['shotZones']['2019']['shotOboxTotal'])
shotzones_2019 = pd.concat([shotPenaltyArea_2019,shotOboxTotal_2019])

shotPenaltyArea_2016 = pd.json_normalize(data['shotZones']['2016']['shotPenaltyArea'])
shotOboxTotal_2016 = pd.json_normalize(data['shotZones']['2016']['shotOboxTotal'])
shotSixYardBox_2016 = pd.json_normalize(data['shotZones']['2016']['shotSixYardBox'])
shotzones_2016 = pd.concat([shotPenaltyArea_2016,shotOboxTotal_2016,
                            shotSixYardBox_2016])

shotPenaltyArea_2015 = pd.json_normalize(data['shotZones']['2015']['shotPenaltyArea'])
shotOboxTotal_2015 = pd.json_normalize(data['shotZones']['2015']['shotOboxTotal'])
shotSixYardBox_2015 = pd.json_normalize(data['shotZones']['2015']['shotSixYardBox'])
shotzones_2015 = pd.concat([shotPenaltyArea_2015,shotOboxTotal_2015,
                            shotSixYardBox_2015])

shotPenaltyArea_2014 = pd.json_normalize(data['shotZones']['2014']['shotPenaltyArea'])
shotOboxTotal_2014 = pd.json_normalize(data['shotZones']['2014']['shotOboxTotal'])
shotSixYardBox_2014 = pd.json_normalize(data['shotZones']['2014']['shotSixYardBox'])
shotzones_2014 = pd.concat([shotPenaltyArea_2014,shotOboxTotal_2014,
                            shotSixYardBox_2014])

shotzones_all = pd.concat([shotzones_2014,shotzones_2015,shotzones_2016,shotzones_2019,
                           shotzones_2020,shotzones_2021,shotzones_2022,shotzones_2023])
shotzones_all[['goals','shots','xG','assists','xA',
                'key_passes','npg','npxG']] = shotzones_all[['goals','shots','xG','assists','xA',
                'key_passes','npg','npxG']].apply(pd.to_numeric)
shotzones_all.drop(['season'],axis=1,inplace=True)
shotzones_all = shotzones_all.groupby('shotZones').sum()
shotzones_all.loc['total']= shotzones_all.sum()
shotzones_all
# Out:
#                  goals  shots         xG  assists  key_passes         xA  \
# shotZones
# shotOboxTotal     11.0  346.0  11.612470      8.0       149.0   4.369692
# shotPenaltyArea   45.0  200.0  42.408685     32.0       334.0  42.610093
# shotSixYardBox     2.0   11.0   4.286562      6.0        35.0  11.987613
# total             58.0  557.0  58.307717     46.0       518.0  58.967398
#
#                   npg       npxG
# shotZones
# shotOboxTotal    11.0  11.612470
# shotPenaltyArea  28.0  25.662819
# shotSixYardBox    2.0   4.286562
# total            41.0  41.561850

# %%
right_2023 = pd.json_normalize(data['shotTypes']['2023']['RightFoot'])
left_2023 = pd.json_normalize(data['shotTypes']['2023']['LeftFoot'])
head_2023 = pd.json_normalize(data['shotTypes']['2023']['Head'])
shottypes_2023 = pd.concat([right_2023,left_2023,head_2023])
shottypes_2023[['goals','shots','xG','assists','xA',
                'key_passes','npg','npxG']] = shottypes_2023[['goals','shots','xG','assists','xA',
                'key_passes','npg','npxG']].apply(pd.to_numeric)
shottypes_2023.drop(['season'],axis=1,inplace=True)
shottypes_2023 = shottypes_2023.groupby('shotTypes').sum()
shottypes_2023.loc['total']= shottypes_2023.sum()
shottypes_2023
# Out:
#            goals  shots        xG  assists  key_passes        xA  npg  \
# shotTypes
# Head         0.0    2.0  0.479909      1.0        20.0  3.203741  0.0
# LeftFoot     0.0    8.0  0.356792      1.0        24.0  2.091492  0.0
# RightFoot    3.0   46.0  4.605468      3.0        26.0  2.805057  2.0
# total        3.0   56.0  5.442169      5.0        70.0  8.100290  2.0
#
#                npxG
# shotTypes
# Head       0.479909
# LeftFoot   0.356792
# RightFoot  3.083130
# total      3.919831

# %%
right_2023 = pd.json_normalize(data['shotTypes']['2023']['RightFoot'])
left_2023 = pd.json_normalize(data['shotTypes']['2023']['LeftFoot'])
head_2023 = pd.json_normalize(data['shotTypes']['2023']['Head'])
shottypes_2023 = pd.concat([right_2023,left_2023,head_2023])

right_2022 = pd.json_normalize(data['shotTypes']['2022']['RightFoot'])
left_2022 = pd.json_normalize(data['shotTypes']['2022']['LeftFoot'])
head_2022 = pd.json_normalize(data['shotTypes']['2022']['Head'])
shottypes_2022 = pd.concat([right_2022,left_2022,head_2022])

right_2021 = pd.json_normalize(data['shotTypes']['2021']['RightFoot'])
left_2021 = pd.json_normalize(data['shotTypes']['2021']['LeftFoot'])
head_2021 = pd.json_normalize(data['shotTypes']['2021']['Head'])
other_2021 = pd.json_normalize(data['shotTypes']['2021']['OtherBodyPart'])
shottypes_2021 = pd.concat([right_2021,left_2021,head_2021,other_2021])

right_2020 = pd.json_normalize(data['shotTypes']['2020']['RightFoot'])
left_2020 = pd.json_normalize(data['shotTypes']['2020']['LeftFoot'])
head_2020 = pd.json_normalize(data['shotTypes']['2020']['Head'])
shottypes_2020 = pd.concat([right_2020,left_2020,head_2020])

right_2019 = pd.json_normalize(data['shotTypes']['2019']['RightFoot'])
left_2019 = pd.json_normalize(data['shotTypes']['2019']['LeftFoot'])
head_2019 = pd.json_normalize(data['shotTypes']['2019']['Head'])
shottypes_2019 = pd.concat([right_2019,left_2019,head_2019])

right_2016 = pd.json_normalize(data['shotTypes']['2016']['RightFoot'])
left_2016 = pd.json_normalize(data['shotTypes']['2016']['LeftFoot'])
head_2016 = pd.json_normalize(data['shotTypes']['2016']['Head'])
shottypes_2016 = pd.concat([right_2016,left_2016,head_2016])

right_2015 = pd.json_normalize(data['shotTypes']['2015']['RightFoot'])
left_2015 = pd.json_normalize(data['shotTypes']['2015']['LeftFoot'])
head_2015 = pd.json_normalize(data['shotTypes']['2015']['Head'])
shottypes_2015 = pd.concat([right_2015,left_2015,head_2015])

right_2014 = pd.json_normalize(data['shotTypes']['2014']['RightFoot'])
left_2014 = pd.json_normalize(data['shotTypes']['2014']['LeftFoot'])
head_2014 = pd.json_normalize(data['shotTypes']['2014']['Head'])
shottypes_2014 = pd.concat([right_2014,left_2014,head_2014])

shottypes_all = pd.concat([shottypes_2014,shottypes_2015,shottypes_2016,shottypes_2019,
                           shottypes_2020,shottypes_2021,shottypes_2022,shottypes_2023])
shottypes_all[['goals','shots','xG','assists','xA',
                'key_passes','npg','npxG']] = shottypes_all[['goals','shots','xG','assists','xA',
                'key_passes','npg','npxG']].apply(pd.to_numeric)
shottypes_all.drop(['season'],axis=1,inplace=True)
shottypes_all = shottypes_all.groupby('shotTypes').sum()
shottypes_all.loc['total']= shottypes_all.sum()
shottypes_all
# Out:
#                goals  shots         xG  assists  key_passes         xA   npg  \
# shotTypes
# Head             2.0   30.0   3.836019      8.0       114.0  11.573813   2.0
# LeftFoot         4.0   60.0   3.999997     11.0       181.0  21.164847   4.0
# OtherBodyPart    0.0    0.0   0.000000      0.0         1.0   0.040029   0.0
# RightFoot       52.0  467.0  50.471701     27.0       222.0  26.188709  35.0
# total           58.0  557.0  58.307717     46.0       518.0  58.967398  41.0
#
#                     npxG
# shotTypes
# Head            3.836019
# LeftFoot        3.999997
# OtherBodyPart   0.000000
# RightFoot      33.725834
# total          41.561850

# %%
strings2 = scripts[2].string 
ind_start2 = strings2.index("('")+2 
ind_end2 = strings2.index("')") 
json_data2 = strings2[ind_start2:ind_end2] 
json_data2 = json_data2.encode('utf8').decode('unicode_escape')
data2 = json.loads(json_data2)

# %%
#note: this is the data I found within the "scripts", but it's not exactly the stuff you see in 
#the page (per 90 values, radar, seasons menu)
radar_amc = pd.json_normalize(data2['AMC'])
radar_amc.loc[:,'position'] = 'AMC'
radar_aml = pd.json_normalize(data2['AML'])
radar_aml.loc[:,'position'] = 'AML'
radar_amr = pd.json_normalize(data2['AMR'])
radar_amr.loc[:,'position'] = 'AMR'
radar_dmc = pd.json_normalize(data2['DMC'])
radar_dmc.loc[:,'position'] = 'DMC'
radar_fw = pd.json_normalize(data2['FW'])
radar_fw.loc[:,'position'] = 'FW'
radar_fwr = pd.json_normalize(data2['FWR'])
radar_fwr.loc[:,'position'] = 'FWR'
radar_fwl = pd.json_normalize(data2['FWL'])
radar_fwl.loc[:,'position'] = 'FWL'
radar_mc = pd.json_normalize(data2['MC'])
radar_mc.loc[:,'position'] = 'MC'
radar_mr = pd.json_normalize(data2['MR'])
radar_mr.loc[:,'position'] = 'MR'
radar_ml = pd.json_normalize(data2['ML'])
radar_ml.loc[:,'position'] = 'ML'
radar_sub = pd.json_normalize(data2['Sub'])
radar_sub.loc[:,'position'] = 'Sub'
radar_data = pd.concat([radar_amc,radar_aml,radar_amr,radar_dmc,radar_fw,radar_fwr,radar_fwl,
                       radar_mc,radar_mr,radar_ml,radar_sub])
first_column = radar_data.pop('position') 
radar_data.insert(0, 'position', first_column) 
radar_data
# Out:
#   position  goals.min  goals.max  goals.avg    xG.min    xG.max    xG.avg  \
# 0      AMC     0.0003     0.0062     0.0023  0.000660  0.004983  0.002192
# 0      AML     0.0008     0.0047     0.0021  0.001378  0.005330  0.002159
# 0      AMR     0.0007     0.0055     0.0020  0.000999  0.004492  0.001965
# 0      DMC     0.0000     0.0044     0.0006  0.000050  0.003600  0.000667
# 0       FW     0.0011     0.0126     0.0042  0.001728  0.012082  0.004155
# 0      FWR     0.0021     0.0112     0.0031  0.001775  0.009357  0.002976
# 0      FWL     0.0012     0.0118     0.0031  0.001742  0.010550  0.002925
# 0       MC     0.0000     0.0052     0.0009  0.000033  0.003700  0.000922
# 0       MR     0.0007     0.0033     0.0014  0.000812  0.002948  0.001464
# 0       ML     0.0003     0.0032     0.0015  0.000583  0.002587  0.001497
# 0      Sub     0.0008     0.0160     0.0026  0.001212  0.014437  0.002744
#
#    shots.min  shots.max  shots.avg  ...    xA.avg  key_passes.min  \
# 0     0.0111     0.0425     0.0218  ...  0.001843          0.0090
# 0     0.0171     0.0471     0.0219  ...  0.001716          0.0093
# 0     0.0123     0.0362     0.0201  ...  0.001813          0.0121
# 0     0.0016     0.0264     0.0103  ...  0.000639          0.0022
# 0     0.0150     0.0737     0.0280  ...  0.001316          0.0036
# 0     0.0216     0.0562     0.0255  ...  0.002069          0.0187
# 0     0.0188     0.0693     0.0268  ...  0.002104          0.0146
# 0     0.0012     0.0354     0.0124  ...  0.000968          0.0021
# 0     0.0082     0.0262     0.0162  ...  0.001528          0.0092
# 0     0.0101     0.0261     0.0172  ...  0.001521          0.0090
# 0     0.0089     0.0660     0.0249  ...  0.001715          0.0062
#
#    key_passes.max  key_passes.avg  xGChain.min  xGChain.max  xGChain.avg  \
# 0          0.0451          0.0186     0.002750     0.010071     0.004880
# 0          0.0302          0.0158     0.002872     0.010276     0.004629
# 0          0.0365          0.0165     0.003828     0.009059     0.004554
# 0          0.0281          0.0087     0.000955     0.008132     0.003192
# 0          0.0309          0.0120     0.002727     0.016914     0.005338
# 0          0.0349          0.0179     0.004310     0.015081     0.005801
# 0          0.0312          0.0179     0.004491     0.014931     0.005866
# 0          0.0377          0.0115     0.000854     0.012126     0.003672
# 0          0.0195          0.0146     0.002675     0.005248     0.003840
# 0          0.0220          0.0149     0.002416     0.006683     0.003775
# 0          0.0369          0.0162     0.003784     0.016049     0.005900
#
#    xGBuildup.min  xGBuildup.max  xGBuildup.avg
# 0       0.001072       0.006206       0.002221
# 0       0.000892       0.005197       0.001892
# 0       0.001096       0.004356       0.001925
# 0       0.000889       0.006581       0.002538
# 0       0.000243       0.006713       0.001318
# 0       0.001854       0.005891       0.002327
# 0       0.001656       0.005858       0.002326
# 0       0.000642       0.008059       0.002569
# 0       0.001035       0.003009       0.001810
# 0       0.000987       0.003597       0.001802
# 0       0.000342       0.008153       0.002759
#
# [11 rows x 25 columns]

# %%
fw_radar = pd.DataFrame(data2['FW']).T
fw_radar
# Out:
#                  min       max       avg
# goals       0.001100  0.012600  0.004200
# xG          0.001728  0.012082  0.004155
# shots       0.015000  0.073700  0.028000
# assists     0.000000  0.004800  0.001400
# xA          0.000264  0.005382  0.001316
# key_passes  0.003600  0.030900  0.012000
# xGChain     0.002727  0.016914  0.005338
# xGBuildup   0.000243  0.006713  0.001318

# %%
strings3 = scripts[3].string
ind_start3 = strings3.index("('")+2 
ind_end3 = strings3.index("')") 
json_data3 = strings3[ind_start3:ind_end3] 
json_data3 = json_data3.encode('utf8').decode('unicode_escape')
data3 = json.loads(json_data3)
shots_df = pd.DataFrame(data3)
shots_df
# Out:
#          id minute       result                   X                    Y  \
# 0     41640     79  BlockedShot   0.730999984741211   0.5059999847412109
# 1     41641     82  MissedShots  0.9569999694824218   0.6170000076293946
# 2     41643     86    SavedShot                0.77   0.5170000076293946
# 3     41807     47  BlockedShot   0.759000015258789    0.664000015258789
# 4     42170     42  BlockedShot   0.754000015258789    0.534000015258789
# ..      ...    ...          ...                 ...                  ...
# 553  560856     73    SavedShot  0.7719999694824219                 0.56
# 554  560859     79  MissedShots  0.6930000305175781  0.15399999618530275
# 555  560865     90  BlockedShot                0.78  0.46599998474121096
# 556  561598     14    SavedShot  0.7630000305175781   0.6990000152587891
# 557  561618     57  BlockedShot  0.8530000305175781  0.39799999237060546
#
#                        xG           player h_a player_id       situation  \
# 0    0.031210700049996376  Bruno Fernandes   h      1228        OpenPlay
# 1     0.11918000131845474  Bruno Fernandes   h      1228        OpenPlay
# 2    0.037953298538923264  Bruno Fernandes   h      1228        OpenPlay
# 3     0.01848829910159111  Bruno Fernandes   a      1228        OpenPlay
# 4     0.02486089989542961  Bruno Fernandes   h      1228        OpenPlay
# ..                    ...              ...  ..       ...             ...
# 553  0.055911991745233536  Bruno Fernandes   a      1228        OpenPlay
# 554   0.02277890220284462  Bruno Fernandes   a      1228  DirectFreekick
# 555   0.09410039335489273  Bruno Fernandes   a      1228  DirectFreekick
# 556   0.01798064634203911  Bruno Fernandes   h      1228      FromCorner
# 557   0.09840022027492523  Bruno Fernandes   h      1228        OpenPlay
#
#     season   shotType match_id                   h_team             a_team  \
# 0     2014  RightFoot     5158                  Udinese             Empoli
# 1     2014  RightFoot     5158                  Udinese             Empoli
# 2     2014  RightFoot     5158                  Udinese             Empoli
# 3     2014  RightFoot     5110                 Juventus            Udinese
# 4     2014   LeftFoot     5125                  Udinese             Napoli
# ..     ...        ...      ...                      ...                ...
# 553   2023   LeftFoot    22111  Wolverhampton Wanderers  Manchester United
# 554   2023  RightFoot    22111  Wolverhampton Wanderers  Manchester United
# 555   2023  RightFoot    22111  Wolverhampton Wanderers  Manchester United
# 556   2023  RightFoot    22122        Manchester United           West Ham
# 557   2023  RightFoot    22122        Manchester United           West Ham
#
#     h_goals a_goals                 date     player_assisted lastAction
# 0         2       0  2014-08-31 19:45:00       Cyril Théréau       Pass
# 1         2       0  2014-08-31 19:45:00   Antonio Di Natale    Chipped
# 2         2       0  2014-08-31 19:45:00     Panagiotis Kone       Pass
# 3         2       0  2014-09-13 19:45:00   Antonio Di Natale     LayOff
# 4         1       0  2014-09-21 17:00:00       Emmanuel Badu       Pass
# ..      ...     ...                  ...                 ...        ...
# 553       3       4  2024-02-01 20:15:00                None     TakeOn
# 554       3       4  2024-02-01 20:15:00                None   Standard
# 555       3       4  2024-02-01 20:15:00                None   Standard
# 556       3       0  2024-02-04 14:00:00     Marcus Rashford       Pass
# 557       3       0  2024-02-04 14:00:00  Alejandro Garnacho       Pass
#
# [558 rows x 20 columns]

# %%
scripts[4]
# Out:
# <script>
# 	var matchesData	= JSON.parse('\x5B\x7B\x22goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22position\x22\x3A\x22AMC\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Manchester\x20United\x22,\x22h_goals\x22\x3A\x221\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D02\x2D11\x22,\x22id\x22\x3A\x2222125\x22,\x22season\x22\x3A\x222023\x22,\x22roster_id\x22\x3A\x22640948\x22,\x22xA\x22\x3A\x220.78354811668396\x22,\x22assists\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x228\x22,\x22npg\x22\x3A\x220\x22,\x22npxG\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x221.1459511518478394\x22,\x22xGBuildup\x22\x3A\x220.47567039728164673\x22\x7D,\x7B\x22goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x222\x22,\x22xG\x22\x3A\x220.11638087034225464\x22,\x22time\x22\x3A\x2290\x22,\x22position\x22\x3A\x22AMC\x22,\x22h_team\x22\x3A\x22Manchester\x20United\x22,\x22a_team\x22\x3A\x22West\x20Ham\x22,\x22h_goals\x22\x3A\x223\x22,\x22a_goals\x22\x3A\x220\x22,\x22date\x22\x3A\x222024\x2D02\x2D04\x22,\x22id\x22\x3A\x2222122\x22,\x22season\x22\x3A\x222023\x22,\x22roster_id\x22\x3A\x22639077\x22,\x22xA\x22\x3A\x220.10938521474599838\x22,\x22assists\x22\x3A\x221\x22,\x22key_passes\x22\x3A\x223\x22,\x22npg\x22\x3A\x220\x22,\x22npxG\x22\x3A\x220.11638087034225464\x22,\x22xGChain\x22\x3A\x220.37612348794937134\x22,\x22xGBuildup\x22\x3A\x220.21940374374389648\x22\x7D,\x7B\x22goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x225\x22,\x22xG\x22\x3A\x220.39988255500793457\x22,\x22time\x22\x3A\x2290\x22,\x22position\x22\x3A\x22AMC\x22,\x22h_team\x22\x3A\x22Wolverhampton\x20Wanderers\x22,\x22a_team\x22\x3A\x22Manchester\x20United\x22,\x22h_goals\x22\x3A\x223\x22,\x22a_goals\x22\x3A\x224\x22,\x22date\x22\x3A\x222024\x2D02\x2D01\x22,\x22id\x22\x3A\x2222111\x22,\x22season\x22\x3A\x222023\x22,\x22roster_id\x22\x3A\x22638133\x22,\x22xA\x22\x3A\x220.5322843790054321\x22,\x22assists\x22\x3A\x221\x22,\x22key_passes\x22\x3A\x224\x22,\x22npg\x22\x3A\x220\x22,\x22npxG\x22\x3A\x220.39988255500793457\x22,\x22xGChain\x22\x3A\x220.32443317770957947\x22,\x22xGBuildup\x22\x3A\x220.09734188765287399\x22\x7D,\x7B\x22goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x222\x22,\x22xG\x22\x3A\x220.08685034513473511\x22,\x22time\x22\x3A\x2290\x22,\x22position\x22\x3A\x22AMC\x22,\x22h_team\x22\x3A\x22Manchester\x20United\x22,\x22a_team\x22\x3A\x22Tottenham\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222024\x2D01\x2D14\x22,\x22id\x22\x3A\x2222099\x22,\x22season\x22\x3A\x222023\x22,\x22roster_id\x22\x3A\x22635463\x22,\x22xA\x22\x3A\x220.023092025890946388\x22,\x22assists\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x221\x22,\x22npg\x22\x3A\x220\x22,\x22npxG\x22\x3A\x220.08685034513473511\x22,\x22xGChain\x22\x3A\x220.18781150877475739\x22,\x22xGBuildup\x22\x3A\x220.18781150877475739\x22\x7D,\x7B\x22goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x221\x22,\x22xG\x22\x3A\x220.011789972893893719\x22,\x22time\x22\x3A\x2290\x22,\x22position\x22\x3A\x22AMC\x22,\x22h_team\x22\x3A\x22Nottingham\x20Forest\x22,\x22a_team\x22\x3A\x22Manchester\x20United\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x221\x22,\x22date\x22\x3A\x222023\x2D12\x2D30\x22,\x22id\x22\x3A\x2222091\x22,\x22season\x22\x3A\x222023\x22,\x22roster_id\x22\x3A\x22633662\x22,\x22xA\x22\x3A\x220.18041430413722992\x22,\x22assists\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x222\x22,\x22npg\x22\x3A\x220\x22,\x22npxG\x22\x3A\x220.011789972893893719\x22,\x22xGChain\x22\x3A\x220.3882662057876587\x22,\x22xGBuildup\x22\x3A\x220.3882662057876587\x22\x7D,\x7B\x22goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x222\x22,\x22xG\x22\x3A\x220.127362921833992\x22,\x22time\x22\x3A\x2290\x22,\x22position\x22\x3A\x22AMC\x22,\x22h_team\x22\x3A\x22Manchester\x20United\x22,\x22a_team\x22\x3A\x22Aston\x20Villa\x22,\x22h_goals\x22\x3A\x223\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222023\x2D12\x2D26\x22,\x22id\x22\x3A\x2222082\x22,\x22season\x22\x3A\x222023\x22,\x22roster_id\x22\x3A\x2263 ...
# </script>

# %%
strings4 = scripts[4].string
# Getting rid of unnecessary characters from json data
ind_start4 = strings4.index("('")+2 
ind_end4 = strings4.index("')") 
json_data4 = strings4[ind_start4:ind_end4] 
json_data4 = json_data4.encode('utf8').decode('unicode_escape')
data4= json.loads(json_data4)
match_data = pd.DataFrame(data4)
match_data
# Out:
#     goals shots                    xG time position                   h_team  \
# 0       0     0                     0   90      AMC              Aston Villa
# 1       0     2   0.11638087034225464   90      AMC        Manchester United
# 2       0     5   0.39988255500793457   90      AMC  Wolverhampton Wanderers
# 3       0     2   0.08685034513473511   90      AMC        Manchester United
# 4       0     1  0.011789972893893719   90      AMC        Nottingham Forest
# ..    ...   ...                   ...  ...      ...                      ...
# 237     1     2   0.09847020357847214   74      Sub                  Udinese
# 238     0     0                     0   57      Sub                    Lazio
# 239     0     1   0.02486089989542961   70      AMC                  Udinese
# 240     0     1   0.01848829910159111   44      Sub                 Juventus
# 241     0     3   0.18834400177001953   21      Sub                  Udinese
#
#                 a_team h_goals a_goals        date     id season roster_id  \
# 0    Manchester United       1       2  2024-02-11  22125   2023    640948
# 1             West Ham       3       0  2024-02-04  22122   2023    639077
# 2    Manchester United       3       4  2024-02-01  22111   2023    638133
# 3            Tottenham       2       2  2024-01-14  22099   2023    635463
# 4    Manchester United       2       1  2023-12-30  22091   2023    633662
# ..                 ...     ...     ...         ...    ...    ...       ...
# 237             Cesena       1       1  2014-10-05   5074   2014     48156
# 238            Udinese       0       1  2014-09-25   5138   2014     47526
# 239             Napoli       1       0  2014-09-21   5125   2014     47314
# 240            Udinese       2       0  2014-09-13   5110   2014     46940
# 241             Empoli       2       0  2014-08-31   5158   2014     46758
#
#                        xA assists key_passes npg                  npxG  \
# 0        0.78354811668396       0          8   0                     0
# 1     0.10938521474599838       1          3   0   0.11638087034225464
# 2      0.5322843790054321       1          4   0   0.39988255500793457
# 3    0.023092025890946388       0          1   0   0.08685034513473511
# 4     0.18041430413722992       0          2   0  0.011789972893893719
# ..                    ...     ...        ...  ..                   ...
# 237   0.16920700669288635       0          1   1   0.09847020357847214
# 238   0.09006520360708237       0          1   0                     0
# 239                     0       0          0   0   0.02486089989542961
# 240   0.03042370080947876       0          2   0   0.01848829910159111
# 241                     0       0          0   0   0.18834400177001953
#
#                  xGChain             xGBuildup
# 0     1.1459511518478394   0.47567039728164673
# 1    0.37612348794937134   0.21940374374389648
# 2    0.32443317770957947   0.09734188765287399
# 3    0.18781150877475739   0.18781150877475739
# 4     0.3882662057876587    0.3882662057876587
# ..                   ...                   ...
# 237   0.2905159890651703   0.19204600155353546
# 238  0.09006520360708237   0.09006520360708237
# 239  0.02486089989542961                     0
# 240  0.04891189932823181  0.017866799607872963
# 241  0.28020599484443665   0.09186259657144547
#
# [242 rows x 20 columns]
