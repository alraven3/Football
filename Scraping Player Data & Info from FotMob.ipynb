# %% [markdown]
# **This is a scraper to extract info/data from FotMob's player profiles, based on the example of Leroy Sané**

# %%
import requests
from bs4 import BeautifulSoup

# %%
import pandas as pd
import json

# %%
url = 'https://www.fotmob.com/players/530859/leroy-sane'
page = requests.get(url)
soup = BeautifulSoup(page.text,'html.parser')
scripts = soup.find_all('script')

# %%
json_script = scripts[58].string

# %%
data = json.loads(json_script)

# %%
data = data['props']['pageProps']['data']

# %%
data['name']
# Out:
# 'Leroy Sané'

# %%
data['birthDate']['utcTime']
# Out:
# '1996-01-11T00:00:00.000Z'

# %%
data['primaryTeam']['teamName']
# Out:
# 'Bayern München'

# %%
data['primaryTeam']['teamColors']
# Out:
# {'color': '#C60428',
#  'colorAlternate': '#DC052D',
#  'colorAway': '#292229',
#  'colorAwayAlternate': '#FFFFFF'}

# %%
data['positionDescription']['primaryPosition']
# Out:
# {'label': 'Right Winger', 'key': 'rightwinger'}

# %%
data['positionDescription']['nonPrimaryPositions']
# Out:
# [{'label': 'Attacking Midfielder', 'key': 'centerattackingmidfielder'},
#  {'label': 'Left Winger', 'key': 'leftwinger'},
#  {'label': 'Striker', 'key': 'striker'}]

# %%
positions = data['positionDescription']['positions']
positions = pd.json_normalize(positions)
positions
# Out:
#    occurences position  isMainPosition  pitchPositionData  \
# 0           1       73           False                NaN
# 1          27       82            True                NaN
# 2           6       84           False                NaN
# 3          16       87           False                NaN
# 4           2      104           False                NaN
#
#            strPos.label                 strPos.key strPosShort.label  \
# 0    Central Midfielder           centermidfielder                CM
# 1          Right Winger                rightwinger                RW
# 2  Attacking Midfielder  centerattackingmidfielder                AM
# 3           Left Winger                 leftwinger                LW
# 4               Striker                    striker                ST
#
#                    strPosShort.key  pitchPositionData.right  \
# 0           centermidfielder_short                      NaN
# 1                rightwinger_short                     0.83
# 2  centerattackingmidfielder_short                     0.50
# 3                 leftwinger_short                     0.17
# 4                    striker_short                     0.50
#
#    pitchPositionData.top  pitchPositionData.ratio
# 0                    NaN                      NaN
# 1                   0.26                      NaN
# 2                   0.26                 0.315385
# 3                   0.26                 0.507692
# 4                   0.10                 0.238462

# %%
player_info = data['playerInformation']
player_info = pd.json_normalize(player_info)
player_info
# Out:
#             title        translationKey value.key value.fallback countryCode  \
# 0          Height   height_sentencecase      None         183 cm         NaN
# 1           Shirt                 shirt      None             10         NaN
# 2             Age      age_sentencecase      None             27         NaN
# 3  Preferred foot        preferred_foot      left           Left         NaN
# 4         Country  country_sentencecase      None        Germany         GER
# 5    Market value        transfer_value      None           €68M         NaN
#
#   icon.type icon.id
# 0       NaN     NaN
# 1       NaN     NaN
# 2       NaN     NaN
# 3       NaN     NaN
# 4   country     GER
# 5       NaN     NaN

# %%
mainLeague_name = data['mainLeague']['leagueName']
mainLeague_name
# Out:
# 'Bundesliga 2023/2024'

# %%
data['mainLeague']
# Out:
# {'topStats': {'id': 'top-stat-card',
#   'type': 'stat-values',
#   'display': 'top-stat-card',
#   'items': [{'title': 'Goals',
#     'localizedTitleId': 'goals',
#     'statValue': '8',
#     'per90': 0.547112462006079,
#     'percentileRank': 100,
#     'percentileRankPer90': 94.5945945945946,
#     'statFormat': 'number'},
#    {'title': 'Assists',
#     'localizedTitleId': 'goal_assist_title',
#     'statValue': '8',
#     'per90': 0.547112462006079,
#     'percentileRank': 100,
#     'percentileRankPer90': 91.8918918918919,
#     'statFormat': 'number'},
#    {'title': 'Rating',
#     'localizedTitleId': 'rating',
#     'statValue': '8.31',
#     'per90': 8.306,
#     'percentileRank': 100,
#     'percentileRankPer90': 100,
#     'statFormat': 'fraction'},
#    {'title': 'Matches',
#     'localizedTitleId': 'matches_uppercase',
#     'statValue': '15',
#     'per90': 15,
#     'percentileRank': 74.32432432432432,
#     'percentileRankPer90': 74.32432432432432,
#     'statFormat': 'number'},
#    {'title': 'Started',
#     'localizedTitleId': 'started',
#     'statValue': '15',
#     'per90': 15,
#     'percentileRank': 89.1891891891892,
#     'percentileRankPer90': 40.54054054054054,
#     'statFormat': 'number'},
#    {'title': 'Minutes',
#     'localizedTitleId': 'minutes_played',
#     'statValue': '1316',
#     'per90': 90,
#     'percentileRank': 97.2972972972973,
#     'percentileRankPer90': 100,
#     'statFormat': 'number'}]},
#  'leagueId': 54,
#  'leagueName': 'Bundesliga 2023/2024'}

# %%
mainLeague = data['mainLeague']
mainLeague = pd.json_normalize(mainLeague)
mainLeague
# Out:
#    leagueId            leagueName    topStats.id topStats.type  \
# 0        54  Bundesliga 2023/2024  top-stat-card   stat-values
#
#   topStats.display                                     topStats.items
# 0    top-stat-card  [{'title': 'Goals', 'localizedTitleId': 'goals...

# %%
trophies = data['trophies']['playerTrophies']
trophies = pd.json_normalize(trophies)
trophies
# Out:
#   ccode  teamId         teamName  \
# 0   GER    9823   Bayern München
# 1   ENG    8456  Manchester City
# 2   INT    8570          Germany
# 3   GER  603864   Schalke 04 U19
#
#                                          tournaments
# 0  [{'ccode': 'GER', 'leagueId': 42, 'leagueName'...
# 1  [{'ccode': 'ENG', 'leagueId': 132, 'leagueName...
# 2  [{'ccode': 'GER', 'leagueId': 43, 'leagueName'...
# 3  [{'ccode': 'GER', 'leagueId': -1, 'leagueName'...

# %%
trophies_bayern = data['trophies']['playerTrophies'][0]['tournaments']
trophies_bayern = pd.json_normalize(trophies_bayern)
trophies_bayern
# Out:
#   ccode  leagueId             leagueName                         seasonsWon  \
# 0   GER        42  UEFA Champions League                        [2019/2020]
# 1   GER        54             Bundesliga  [2022/2023, 2021/2022, 2020/2021]
# 2   GER        74         UEFA Super Cup                        [2020/2021]
# 3   GER      8924              Super Cup  [2022/2023, 2021/2022, 2020/2021]
# 4   GER        78    FIFA Club World Cup                       [2020 Qatar]
#
#   seasonsRunnerUp
# 0              []
# 1              []
# 2              []
# 3     [2023/2024]
# 4              []

# %%
trophies_mancity = data['trophies']['playerTrophies'][1]['tournaments']
trophies_mancity = pd.json_normalize(trophies_mancity)
trophies_mancity
# Out:
#   ccode  leagueId        leagueName                         seasonsWon  \
# 0   ENG       132            FA Cup                        [2018/2019]
# 1   ENG        47    Premier League             [2018/2019, 2017/2018]
# 2   ENG       133        League Cup  [2019/2020, 2018/2019, 2017/2018]
# 3   ENG       247  Community Shield             [2019/2020, 2018/2019]
#
#   seasonsRunnerUp
# 0              []
# 1              []
# 2              []
# 3              []

# %%
recentMatches = data['recentMatches']
recentMatches = pd.json_normalize(recentMatches)
recentMatches
# Out:
#     teamId        teamName  opponentTeamId     opponentTeamName  isHomeTeam  \
# 0     9823  Bayern München            8721            Wolfsburg       False
# 1     9823  Bayern München           10269        VfB Stuttgart        True
# 2     9823  Bayern München           10260    Manchester United       False
# 3     9823  Bayern München            9810  Eintracht Frankfurt       False
# 4     9823  Bayern München            8391         FC København        True
# ..     ...             ...             ...                  ...         ...
# 57    9823  Bayern München            9905             Mainz 05       False
# 58    9823  Bayern München            9810  Eintracht Frankfurt        True
# 59    9823  Bayern München            8722           1. FC Köln        True
# 60    9823  Bayern München          178475           RB Leipzig       False
# 61    9823  Bayern München           10013             Salzburg        True
#
#          id                                       matchPageUrl  leagueId  \
# 0   4221879  /matches/wolfsburg-vs-bayern-munchen/2udogn#42...        54
# 1   4221986  /matches/bayern-munchen-vs-vfb-stuttgart/3c6nc...        54
# 2   4315006  /matches/bayern-munchen-vs-manchester-united/3...        42
# 3   4221979  /matches/eintracht-frankfurt-vs-bayern-munchen...        54
# 4   4315005  /matches/fc-kobenhavn-vs-bayern-munchen/2qrohw...        42
# ..      ...                                                ...       ...
# 57  4053739  /matches/bayern-munchen-vs-mainz-05/37vb95#405...       209
# 58  3903697  /matches/eintracht-frankfurt-vs-bayern-munchen...        54
# 59  3903688  /matches/1-fc-koln-vs-bayern-munchen/2ue2rs#39...        54
# 60  3903680  /matches/bayern-munchen-vs-rb-leipzig/856w9cm#...        54
# 61  4067521  /matches/bayern-munchen-vs-salzburg/3953qd#406...       489
#
#                  leagueName stage  ...  minutesPlayed  goals  assists  \
# 0                Bundesliga  None  ...             90      0        0
# 1                Bundesliga  None  ...             90      0        1
# 2   Champions League Grp. A  None  ...             89      0        0
# 3                Bundesliga  None  ...             90      0        1
# 4   Champions League Grp. A  None  ...             26      0        0
# ..                      ...   ...  ...            ...    ...      ...
# 57                DFB Pokal   1/8  ...             71      1        0
# 58               Bundesliga  None  ...             70      1        0
# 59               Bundesliga  None  ...             90      0        0
# 60               Bundesliga  None  ...             90      0        0
# 61          Club Friendlies  None  ...             63      1        0
#
#     yellowCards  redCards  playerOfTheMatch  onBench  \
# 0             0         0             False    False
# 1             0         0             False    False
# 2             0         0             False    False
# 3             1         0             False    False
# 4             0         0             False    False
# ..          ...       ...               ...      ...
# 57            0         0             False    False
# 58            0         0             False    False
# 59            0         0             False    False
# 60            0         0             False    False
# 61            0         0             False    False
#
#            matchDate.utcTime  ratingProps.num ratingProps.bgcolor
# 0   2023-12-20T20:30:00.000Z              7.2             #1ec853
# 1   2023-12-17T19:30:00.000Z              8.1             #1ec853
# 2   2023-12-12T21:00:00.000Z              7.1             #1ec853
# 3   2023-12-09T15:30:00.000Z              8.1             #1ec853
# 4   2023-11-29T21:00:00.000Z              6.6             #f08022
# ..                       ...              ...                 ...
# 57  2023-02-01T20:45:00.000Z              8.3             #1ec853
# 58  2023-01-28T18:30:00.000Z              7.5             #1ec853
# 59  2023-01-24T20:30:00.000Z              7.0             #1ec853
# 60  2023-01-20T20:30:00.000Z              7.1             #1ec853
# 61  2023-01-13T18:00:00.000Z                0             #989898
#
# [62 rows x 22 columns]

# %%
career_byteam = data['careerHistory']['careerItems']['senior']['teamEntries']+data['careerHistory']['careerItems']['youth']['teamEntries']
career_byteam = pd.json_normalize(career_byteam)
career_byteam
# Out:
#    participantId  teamId                 team teamGender transferType  \
# 0         530859    9823       Bayern München       male         None
# 1         530859    8456      Manchester City       male         None
# 2         530859   10189           Schalke 04       male         None
# 3         530859  357215  Manchester City U23       male         None
# 4         530859  603864       Schalke 04 U19       male         None
#
#              startDate              endDate  active  role appearances goals  \
# 0  2020-07-15T00:00:00                 None    True  None         157    47
# 1  2016-08-02T00:00:00  2020-07-15T00:00:00   False  None         135    39
# 2  2014-03-01T00:00:00  2016-08-02T00:00:00   False  None          57    13
# 3  2020-02-27T00:00:00  2020-07-15T00:00:00   False  None           1     0
# 4  2012-11-23T00:00:00  2015-06-30T00:00:00   False  None          44    16
#
#   assists  hasUncertainData
# 0      42             False
# 1      42             False
# 2       7             False
# 3       0             False
# 4     NaN             False

# %%
career_byseason = data['careerHistory']['careerItems']['senior']['seasonEntries']+data['careerHistory']['careerItems']['youth']['seasonEntries']
career_byseason = pd.json_normalize(career_byseason)
career_byseason
# Out:
#    seasonName appearances goals assists  \
# 0   2023/2024          24     9       9
# 1   2022/2023          44    14       9
# 2   2021/2022          45    14      14
# 3   2020/2021          44    10      10
# 4   2019/2020           2     0       0
# 5   2018/2019          47    16      17
# 6   2017/2018          49    14      19
# 7   2016/2017          37     9       6
# 8   2015/2016          42     9       7
# 9   2014/2015          14     4       0
# 10  2013/2014           1     0       0
# 11  2019/2020           1     0       0
# 12  2014/2015          12     5     NaN
# 13  2013/2014          32    11     NaN
#
#                                       tournamentStats  teamId  \
# 0   [{'leagueId': 54, 'tournamentId': 20946, 'leag...    9823
# 1   [{'leagueId': 54, 'tournamentId': 17801, 'leag...    9823
# 2   [{'leagueId': 54, 'tournamentId': 16494, 'leag...    9823
# 3   [{'leagueId': 54, 'tournamentId': 15481, 'leag...    9823
# 4   [{'leagueId': 47, 'tournamentId': 14022, 'leag...    8456
# 5   [{'leagueId': 47, 'tournamentId': 12776, 'leag...    8456
# 6   [{'leagueId': 47, 'tournamentId': 11522, 'leag...    8456
# 7   [{'leagueId': 47, 'tournamentId': 10418, 'leag...    8456
# 8   [{'leagueId': 54, 'tournamentId': 9556, 'leagu...   10189
# 9   [{'leagueId': 54, 'tournamentId': 8633, 'leagu...   10189
# 10  [{'leagueId': 54, 'tournamentId': 7771, 'leagu...   10189
# 11  [{'tournamentId': -1, 'leagueName': 'Premier L...  357215
# 12  [{'tournamentId': -1, 'leagueName': 'UEFA Yout...  603864
# 13  [{'tournamentId': -1, 'leagueName': 'UEFA Yout...  603864
#
#                    team teamGender transferType rating.num rating.bgcolor
# 0        Bayern München       male         None        7.9        #1ec853
# 1        Bayern München       male         None        7.4        #1ec853
# 2        Bayern München       male         None        7.5        #1ec853
# 3        Bayern München       male         None        7.0        #1ec853
# 4       Manchester City       male         None        6.1        #f08022
# 5       Manchester City       male         None        7.4        #1ec853
# 6       Manchester City       male         None        7.6        #1ec853
# 7       Manchester City       male         None        7.4        #1ec853
# 8            Schalke 04       male         None          -           None
# 9            Schalke 04       male         None          -           None
# 10           Schalke 04       male         None          -           None
# 11  Manchester City U23       male         None          -           None
# 12       Schalke 04 U19       male         None          -           None
# 13       Schalke 04 U19       male         None          -           None

# %%
career_byseason['tournamentStats']
# Out:
# 0     [{'leagueId': 54, 'tournamentId': 20946, 'leag...
# 1     [{'leagueId': 54, 'tournamentId': 17801, 'leag...
# 2     [{'leagueId': 54, 'tournamentId': 16494, 'leag...
# 3     [{'leagueId': 54, 'tournamentId': 15481, 'leag...
# 4     [{'leagueId': 47, 'tournamentId': 14022, 'leag...
# 5     [{'leagueId': 47, 'tournamentId': 12776, 'leag...
# 6     [{'leagueId': 47, 'tournamentId': 11522, 'leag...
# 7     [{'leagueId': 47, 'tournamentId': 10418, 'leag...
# 8     [{'leagueId': 54, 'tournamentId': 9556, 'leagu...
# 9     [{'leagueId': 54, 'tournamentId': 8633, 'leagu...
# 10    [{'leagueId': 54, 'tournamentId': 7771, 'leagu...
# 11    [{'tournamentId': -1, 'leagueName': 'Premier L...
# 12    [{'tournamentId': -1, 'leagueName': 'UEFA Yout...
# 13    [{'tournamentId': -1, 'leagueName': 'UEFA Yout...
# Name: tournamentStats, dtype: object

# %%
summary_22_23 = career_byseason['tournamentStats'][1]
summary_22_23 = pd.json_normalize(summary_22_23)
summary_22_23
# Out:
#    leagueId  tournamentId        leagueName  seasonRating  isFriendly  \
# 0        54         17801        Bundesliga          7.26       False
# 1       209         17692         DFB Pokal          7.83       False
# 2      8924         20738         Super Cup          6.61       False
# 3        42         17697  Champions League          7.64       False
#
#   seasonName goals assists appearances rating.num rating.bgcolor
# 0  2022/2023     8       7          32        7.3        #1ec853
# 1  2022/2023     1       1           3        7.8        #1ec853
# 2  2022/2023     1       0           1        6.6        #f08022
# 3  2022/2023     4       1           8        7.6        #1ec853

# %%
traits = data['traits']['items']
traits = pd.json_normalize(traits)
traits
# Out:
#                  key              title     value
# 0    chances_created    Chances created  0.856115
# 1        aerials_won       Aerial duels  0.064748
# 2  defensive_actions  Defensive actions  0.248201
# 3              goals              Goals  0.687050
# 4      shot_attempts      Shot attempts  0.852518
# 5            touches            Touches  0.827338

# %%
response = requests.get(
    'https://www.fotmob.com/api/playerStats?playerId=530859&seasonId=2023%2F2024-54',
    headers={'User-Agent': 'Mozilla/5.0'} # you'll be blocked if you don't use some type of user agent
)
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/116.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    # 'Accept-Encoding': 'gzip, deflate, br',
    'Prefer': 'safe',
    'Referer': 'https://www.sofascore.com/',
    'Origin': 'https://www.sofascore.com',
    'DNT': '1',
    'Connection': 'keep-alive',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-site',
    'Sec-GPC': '1',
    'Cache-Control': 'max-age=0',
    # Requests doesn't support trailers
    # 'TE': 'trailers',
}

response = requests.get('https://www.fotmob.com/api/playerStats?playerId=530859&seasonId=2023%2F2024-54', headers=headers)

# %%
playerStats = response.json()

# %%
top_stats = playerStats['topStatCard']['items']
top_stats = pd.json_normalize(top_stats)
top_stats
# Out:
#      title   localizedTitleId statValue      per90  percentileRank  \
# 0    Goals              goals         8   0.547112      100.000000
# 1  Assists  goal_assist_title         8   0.547112      100.000000
# 2   Rating             rating      8.31   8.306000      100.000000
# 3  Matches  matches_uppercase        15  15.000000       74.324324
# 4  Started            started        15  15.000000       89.189189
# 5  Minutes     minutes_played      1316  90.000000       97.297297
#
#    percentileRankPer90 statFormat
# 0            94.594595     number
# 1            91.891892     number
# 2           100.000000   fraction
# 3            74.324324     number
# 4            40.540541     number
# 5           100.000000     number

# %%
shooting_stats = playerStats['statsSection']['items'][0]['items']
shooting_stats = pd.json_normalize(shooting_stats)
shooting_stats
# Out:
#               title          localizedTitleId statValue     per90  \
# 0             Goals                     goals         8  0.547112
# 1                xG            expected_goals      8.65  0.591538
# 2              xGOT  expected_goals_on_target      9.47  0.647610
# 3  xG excl. penalty            non_penalty_xg      8.65  0.591538
# 4             Shots                     shots        46  3.145897
# 5   Shots on target             ShotsOnTarget        22  1.504559
#
#    percentileRank  percentileRankPer90 statFormat
# 0             100            94.594595     number
# 1             100            94.594595   fraction
# 2             100            94.594595   fraction
# 3             100            95.945946   fraction
# 4             100            82.432432     number
# 5             100            89.189189     number

# %%
passing_stats = playerStats['statsSection']['items'][1]['items']
passing_stats = pd.json_normalize(passing_stats)
passing_stats
# Out:
#                  title               localizedTitleId statValue      per90  \
# 0              Assists                        assists         8   0.547112
# 1                   xA               expected_assists      6.84   0.468071
# 2      Accurate passes              successful_passes       506  34.604863
# 3        Pass accuracy     successful_passes_accuracy      84.5  84.474124
# 4  Accurate long balls            long_balls_accurate        14   0.957447
# 5   Long ball accuracy  long_ball_succeeeded_accuracy      73.7  73.684211
# 6      Chances created                chances_created        49   3.351064
# 7   Successful crosses             crosses_succeeeded        20   1.367781
# 8       Cross accuracy    crosses_succeeeded_accuracy      35.1  35.087719
#
#    percentileRank  percentileRankPer90 statFormat
# 0      100.000000            91.891892     number
# 1      100.000000            97.297297   fraction
# 2       94.594595            79.729730     number
# 3       83.783784            83.783784    percent
# 4       87.837838            62.162162     number
# 5       89.189189            89.189189    percent
# 6      100.000000            95.945946     number
# 7       93.243243            83.783784     number
# 8       82.432432            82.432432    percent

# %%
possession_stats = playerStats['statsSection']['items'][2]['items']
possession_stats = pd.json_normalize(possession_stats)
possession_stats
# Out:
#                        title      localizedTitleId statValue      per90  \
# 0                   Dribbles    dribbles_succeeded        63   4.308511
# 1      Dribbles success rate  won_contest_subtitle      58.9  58.878505
# 2                    Touches               touches       962  65.790274
# 3  Touches in opposition box       touches_opp_box       103   7.044073
# 4               Dispossessed          dispossessed        29   1.983283
# 5                  Fouls won             fouls_won        15   1.025836
#
#    percentileRank  percentileRankPer90 statFormat
# 0      100.000000           100.000000     number
# 1       83.783784            83.783784    percent
# 2       95.945946            85.135135     number
# 3      100.000000            91.891892     number
# 4        1.351351            25.675676     number
# 5       77.027027            40.540541     number

# %%
defending_stats = playerStats['statsSection']['items'][3]['items']
defending_stats = pd.json_normalize(defending_stats)
defending_stats
# Out:
#                        title             localizedTitleId statValue  \
# 0                Tackles won            tackles_succeeded         5
# 1              Tackles won %    tackles_succeeded_percent      50.0
# 2                  Duels won                     duel_won        89
# 3                Duels won %             duel_won_percent      47.8
# 4                Aerials won                  aerials_won         1
# 5              Aerials won %          aerials_won_percent      33.3
# 6              Interceptions                interceptions         3
# 7    Blocked scoring attempt                 shot_blocked        13
# 8                 Recoveries                   recoveries        53
# 9   Possession won final 3rd  poss_won_att_3rd_team_title        10
# 10             Dribbled past                dribbled_past         7
#
#         per90  percentileRank  percentileRankPer90 statFormat
# 0    0.341945       47.297297            18.918919     number
# 1   50.000000       28.378378            28.378378    percent
# 2    6.086626      100.000000            66.216216     number
# 3   47.849462       74.324324            74.324324    percent
# 4    0.068389       10.810811            10.810811     number
# 5   33.333333       41.891892            41.891892    percent
# 6    0.205167       48.648649            25.675676     number
# 7    0.889058      100.000000            83.783784     number
# 8    3.624620       81.081081            24.324324     number
# 9    0.683891       86.486486            58.108108     number
# 10   0.478723       32.432432            81.081081     number

# %%
discipline_stats = playerStats['statsSection']['items'][4]['items']
discipline_stats = pd.json_normalize(discipline_stats)
discipline_stats
# Out:
#           title localizedTitleId statValue     per90  percentileRank  \
# 0  Yellow cards     yellow_cards         2  0.136778       10.810811
# 1     Red cards        red_cards         0  0.000000      100.000000
#
#    percentileRankPer90 statFormat
# 0            55.405405     number
# 1           100.000000     number

# %%
response2 = requests.get('https://www.fotmob.com/api/playerData?id=530859', headers=headers)
playerData = response2.json()
#basically, all of the above is contained here, we could have done the same 
#selections and dataframes starting from "playerData"
#playerData (uncomment to see the JSON, it's obviously very long)
